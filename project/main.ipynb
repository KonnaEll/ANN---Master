# %%
from google.colab import drive
drive.mount('/content/drive/')
# !mkdir scene_data

# !cp drive/MyDrive/Scene.zip /content/scene_data
# Out:
# Mounted at /content/drive/

# %%
cd scene_data/
# Out:
# /content/scene_data

# %%
# !unzip Scene.zip

# !rm -r Scene.zip
# Out:
# Archive:  Scene.zip
#    creating: 15-Scene/15-Scene/
#    creating: 15-Scene/15-Scene/00/
#   inflating: 15-Scene/15-Scene/00/1.jpg
#   inflating: 15-Scene/15-Scene/00/10.jpg
#  extracting: 15-Scene/15-Scene/00/100.jpg
#  extracting: 15-Scene/15-Scene/00/101.jpg
#  extracting: 15-Scene/15-Scene/00/102.jpg
#  extracting: 15-Scene/15-Scene/00/103.jpg
#  extracting: 15-Scene/15-Scene/00/104.jpg
#  extracting: 15-Scene/15-Scene/00/105.jpg
#  extracting: 15-Scene/15-Scene/00/106.jpg
#  extracting: 15-Scene/15-Scene/00/107.jpg
#  extracting: 15-Scene/15-Scene/00/108.jpg
#  extracting: 15-Scene/15-Scene/00/109.jpg
#   inflating: 15-Scene/15-Scene/00/11.jpg
#  extracting: 15-Scene/15-Scene/00/110.jpg
#  extracting: 15-Scene/15-Scene/00/111.jpg
#  extracting: 15-Scene/15-Scene/00/112.jpg
#  extracting: 15-Scene/15-Scene/00/113.jpg
#  extracting: 15-Scene/15-Scene/00/114.jpg
#  extracting: 15-Scene/15-Scene/00/115.jpg
#  extracting: 15-Scene/15-Scene/00/116.jpg
#   inflating: 15-Scene/15-Scene/00/117.jpg
#  extracting: 15-Scene/15-Scene/00/118.jpg
#  extracting: 15-Scene/15-Scene/00/119.jpg
#   inflating: 15-Scene/15-Scene/00/12.jpg
#  extracting: 15-Scene/15-Scene/00/120.jpg
#  extracting: 15-Scene/15-Scene/00/121.jpg
#  extracting: 15-Scene/15-Scene/00/122.jpg
#   inflating: 15-Scene/15-Scene/00/123.jpg
#  extracting: 15-Scene/15-Scene/00/124.jpg
#   inflating: 15-Scene/15-Scene/00/125.jpg
#  extracting: 15-Scene/15-Scene/00/126.jpg
#  extracting: 15-Scene/15-Scene/00/127.jpg
#  extracting: 15-Scene/15-Scene/00/128.jpg
#   inflating: 15-Scene/15-Scene/00/129.jpg
#   inflating: 15-Scene/15-Scene/00/13.jpg
#  extracting: 15-Scene/15-Scene/00/130.jpg
#   inflating: 15-Scene/15-Scene/00/131.jpg
#   inflating: 15-Scene/15-Scene/00/132.jpg
#  extracting: 15-Scene/15-Scene/00/133.jpg
#   inflating: 15-Scene/15-Scene/00/134.jpg
#  extracting: 15-Scene/15-Scene/00/135.jpg
#  extracting: 15-Scene/15-Scene/00/136.jpg
#  extracting: 15-Scene/15-Scene/00/137.jpg
#  extracting: 15-Scene/15-Scene/00/138.jpg
#  extracting: 15-Scene/15-Scene/00/139.jpg
#   inflating: 15-Scene/15-Scene/00/14.jpg
#  extracting: 15-Scene/15-Scene/00/140.jpg
#   inflating: 15-Scene/15-Scene/00/141.jpg
#   inflating: 15-Scene/15-Scene/00/142.jpg
#   inflating: 15-Scene/15-Scene/00/143.jpg
#  extracting: 15-Scene/15-Scene/00/144.jpg
#  extracting: 15-Scene/15-Scene/00/145.jpg
#  extracting: 15-Scene/15-Scene/00/146.jpg
#  extracting: 15-Scene/15-Scene/00/147.jpg
#   inflating: 15-Scene/15-Scene/00/148.jpg
#  extracting: 15-Scene/15-Scene/00/149.jpg
#   inflating: 15-Scene/15-Scene/00/15.jpg
#  extracting: 15-Scene/15-Scene/00/150.jpg
#  extracting: 15-Scene/15-Scene/00/151.jpg
#  extracting: 15-Scene/15-Scene/00/152.jpg
#  extracting: 15-Scene/15-Scene/00/153.jpg
#  extracting: 15-Scene/15-Scene/00/154.jpg
#  extracting: 15-Scene/15-Scene/00/155.jpg
#  extracting: 15-Scene/15-Scene/00/156.jpg
#  extracting: 15-Scene/15-Scene/00/157.jpg
#  extracting: 15-Scene/15-Scene/00/158.jpg
#  extracting: 15-Scene/15-Scene/00/159.jpg
#   inflating: 15-Scene/15-Scene/00/16.jpg
#  extracting: 15-Scene/15-Scene/00/160.jpg
#  extracting: 15-Scene/15-Scene/00/161.jpg
#  extracting: 15-Scene/15-Scene/00/162.jpg
#  extracting: 15-Scene/15-Scene/00/163.jpg
#  extracting: 15-Scene/15-Scene/00/164.jpg
#  extracting: 15-Scene/15-Scene/00/165.jpg
#  extracting: 15-Scene/15-Scene/00/166.jpg
#  extracting: 15-Scene/15-Scene/00/167.jpg
#  extracting: 15-Scene/15-Scene/00/168.jpg
#  extracting: 15-Scene/15-Scene/00/169.jpg
#   inflating: 15-Scene/15-Scene/00/17.jpg
#  extracting: 15-Scene/15-Scene/00/170.jpg
#  extracting: 15-Scene/15-Scene/00/171.jpg
#   inflating: 15-Scene/15-Scene/00/172.jpg
#  extracting: 15-Scene/15-Scene/00/173.jpg
#  extracting: 15-Scene/15-Scene/00/174.jpg
#  extracting: 15-Scene/15-Scene/00/175.jpg
#  extracting: 15-Scene/15-Scene/00/176.jpg
#  extracting: 15-Scene/15-Scene/00/177.jpg
#  extracting: 15-Scene/15-Scene/00/178.jpg
#  extracting: 15-Scene/15-Scene/00/179.jpg
#   inflating: 15-Scene/15-Scene/00/18.jpg
#  extracting: 15-Scene/15-Scene/00/180.jpg
#  extracting: 15-Scene/15-Scene/00/181.jpg
#  extracting: 15-Scene/15-Scene/00/182.jpg
#  extracting: 15-Scene/15-Scene/00/183.jpg
#  extracting: 15-Scene/15-Scene/00/184.jpg
#  extracting: 15-Scene/15-Scene/00/185.jpg
#  extracting: 15-Scene/15-Scene/00/186.jpg
#  extracting: 15-Scene/15-Scene/00/187.jpg
#  extracting: 15-Scene/15-Scene/00/188.jpg
#  extracting: 15-Scene/15-Scene/00/189.jpg
#   inflating: 15-Scene/15-Scene/00/19.jpg
#  extracting: 15-Scene/15-Scene/00/190.jpg
#  extracting: 15-Scene/15-Scene/00/191.jpg
#   inflating: 15-Scene/15-Scene/00/192.jpg
#  extracting: 15-Scene/15-Scene/00/193.jpg
#  extracting: 15-Scene/15-Scene/00/194.jpg
#  extracting: 15-Scene/15-Scene/00/195.jpg
#   inflating: 15-Scene/15-Scene/00/196.jpg
#  extracting: 15-Scene/15-Scene/00/197.jpg
#  extracting: 15-Scene/15-Scene/00/198.jpg
#  extracting: 15-Scene/15-Scene/00/199.jpg
#   inflating: 15-Scene/15-Scene/00/2.jpg
#   inflating: 15-Scene/15-Scene/00/20.jpg
#  extracting: 15-Scene/15-Scene/00/200.jpg
#  extracting: 15-Scene/15-Scene/00/201.jpg
#  extracting: 15-Scene/15-Scene/00/202.jpg
#  extracting: 15-Scene/15-Scene/00/203.jpg
#   inflating: 15-Scene/15-Scene/00/204.jpg
#  extracting: 15-Scene/15-Scene/00/205.jpg
#  extracting: 15-Scene/15-Scene/00/206.jpg
#  extracting: 15-Scene/15-Scene/00/207.jpg
#   inflating: 15-Scene/15-Scene/00/208.jpg
#   inflating: 15-Scene/15-Scene/00/209.jpg
#   inflating: 15-Scene/15-Scene/00/21.jpg
#  extracting: 15-Scene/15-Scene/00/210.jpg
#   inflating: 15-Scene/15-Scene/00/211.jpg
#  extracting: 15-Scene/15-Scene/00/212.jpg
#  extracting: 15-Scene/15-Scene/00/213.jpg
#   inflating: 15-Scene/15-Scene/00/214.jpg
#  extracting: 15-Scene/15-Scene/00/215.jpg
#  extracting: 15-Scene/15-Scene/00/216.jpg
#   inflating: 15-Scene/15-Scene/00/22.jpg
#   inflating: 15-Scene/15-Scene/00/23.jpg
#   inflating: 15-Scene/15-Scene/00/24.jpg
#   inflating: 15-Scene/15-Scene/00/25.jpg
#   inflating: 15-Scene/15-Scene/00/26.jpg
#   inflating: 15-Scene/15-Scene/00/27.jpg
#   inflating: 15-Scene/15-Scene/00/28.jpg
#   inflating: 15-Scene/15-Scene/00/29.jpg
#   inflating: 15-Scene/15-Scene/00/3.jpg
#   inflating: 15-Scene/15-Scene/00/30.jpg
#   inflating: 15-Scene/15-Scene/00/31.jpg
#   inflating: 15-Scene/15-Scene/00/32.jpg
#   inflating: 15-Scene/15-Scene/00/33.jpg
#   inflating: 15-Scene/15-Scene/00/34.jpg
#   inflating: 15-Scene/15-Scene/00/35.jpg
#   inflating: 15-Scene/15-Scene/00/36.jpg
#   inflating: 15-Scene/15-Scene/00/37.jpg
#   inflating: 15-Scene/15-Scene/00/38.jpg
#   inflating: 15-Scene/15-Scene/00/39.jpg
#   inflating: 15-Scene/15-Scene/00/4.jpg
#   inflating: 15-Scene/15-Scene/00/40.jpg
#   inflating: 15-Scene/15-Scene/00/41.jpg
#   inflating: 15-Scene/15-Scene/00/42.jpg
#   inflating: 15-Scene/15-Scene/00/43.jpg
#   inflating: 15-Scene/15-Scene/00/44.jpg
#   inflating: 15-Scene/15-Scene/00/45.jpg
#   inflating: 15-Scene/15-Scene/00/46.jpg
#   inflating: 15-Scene/15-Scene/00/47.jpg
#   inflating: 15-Scene/15-Scene/00/48.jpg
#   inflating: 15-Scene/15-Scene/00/49.jpg
#   inflating: 15-Scene/15-Scene/00/5.jpg
#   inflating: 15-Scene/15-Scene/00/50.jpg
#   inflating: 15-Scene/15-Scene/00/51.jpg
#   inflating: 15-Scene/15-Scene/00/52.jpg
#   inflating: 15-Scene/15-Scene/00/53.jpg
#  extracting: 15-Scene/15-Scene/00/54.jpg
#   inflating: 15-Scene/15-Scene/00/55.jpg
#   inflating: 15-Scene/15-Scene/00/56.jpg
#  extracting: 15-Scene/15-Scene/00/57.jpg
#   inflating: 15-Scene/15-Scene/00/58.jpg
#  extracting: 15-Scene/15-Scene/00/59.jpg
#   inflating: 15-Scene/15-Scene/00/6.jpg
#  extracting: 15-Scene/15-Scene/00/60.jpg
#   inflating: 15-Scene/15-Scene/00/61.jpg
#  extracting: 15-Scene/15-Scene/00/62.jpg
#  extracting: 15-Scene/15-Scene/00/63.jpg
#  extracting: 15-Scene/15-Scene/00/64.jpg
#  extracting: 15-Scene/15-Scene/00/65.jpg
#  extracting: 15-Scene/15-Scene/00/66.jpg
#  extracting: 15-Scene/15-Scene/00/67.jpg
#  extracting: 15-Scene/15-Scene/00/68.jpg
#  extracting: 15-Scene/15-Scene/00/69.jpg
#   inflating: 15-Scene/15-Scene/00/7.jpg
#  extracting: 15-Scene/15-Scene/00/70.jpg
#  extracting: 15-Scene/15-Scene/00/71.jpg
#  extracting: 15-Scene/15-Scene/00/72.jpg
#  extracting: 15-Scene/15-Scene/00/73.jpg
#  extracting: 15-Scene/15-Scene/00/74.jpg
#   inflating: 15-Scene/15-Scene/00/75.jpg
#  extracting: 15-Scene/15-Scene/00/76.jpg
#   inflating: 15-Scene/15-Scene/00/77.jpg
#  extracting: 15-Scene/15-Scene/00/78.jpg
#  extracting: 15-Scene/15-Scene/00/79.jpg
#   inflating: 15-Scene/15-Scene/00/8.jpg
#  extracting: 15-Scene/15-Scene/00/80.jpg
#   inflating: 15-Scene/15-Scene/00/81.jpg
#  extracting: 15-Scene/15-Scene/00/82.jpg
#  extracting: 15-Scene/15-Scene/00/83.jpg
#  extracting: 15-Scene/15-Scene/00/84.jpg
#   inflating: 15-Scene/15-Scene/00/85.jpg
#  extracting: 15-Scene/15-Scene/00/86.jpg
#   inflating: 15-Scene/15-Scene/00/87.jpg
#   inflating: 15-Scene/15-Scene/00/88.jpg
#   inflating: 15-Scene/15-Scene/00/89.jpg
#   inflating: 15-Scene/15-Scene/00/9.jpg
#  extracting: 15-Scene/15-Scene/00/90.jpg
#   inflating: 15-Scene/15-Scene/00/91.jpg
#  extracting: 15-Scene/15-Scene/00/92.jpg
#  extracting: 15-Scene/15-Scene/00/93.jpg
#  extracting: 15-Scene/15-Scene/00/94.jpg
#   inflating: 15-Scene/15-Scene/00/95.jpg
#   inflating: 15-Scene/15-Scene/00/96.jpg
#  extracting: 15-Scene/15-Scene/00/97.jpg
#  extracting: 15-Scene/15-Scene/00/98.jpg
#   inflating: 15-Scene/15-Scene/00/99.jpg
#    creating: 15-Scene/15-Scene/01/
#   inflating: 15-Scene/15-Scene/01/217.jpg
#   inflating: 15-Scene/15-Scene/01/218.jpg
#  extracting: 15-Scene/15-Scene/01/219.jpg
#  extracting: 15-Scene/15-Scene/01/220.jpg
#   inflating: 15-Scene/15-Scene/01/221.jpg
#  extracting: 15-Scene/15-Scene/01/222.jpg
#   inflating: 15-Scene/15-Scene/01/223.jpg
#  extracting: 15-Scene/15-Scene/01/224.jpg
#  extracting: 15-Scene/15-Scene/01/225.jpg
#  extracting: 15-Scene/15-Scene/01/226.jpg
#  extracting: 15-Scene/15-Scene/01/227.jpg
#  extracting: 15-Scene/15-Scene/01/228.jpg
#  extracting: 15-Scene/15-Scene/01/229.jpg
#   inflating: 15-Scene/15-Scene/01/230.jpg
#  extracting: 15-Scene/15-Scene/01/231.jpg
#   inflating: 15-Scene/15-Scene/01/232.jpg
#   inflating: 15-Scene/15-Scene/01/233.jpg
#   inflating: 15-Scene/15-Scene/01/234.jpg
#   inflating: 15-Scene/15-Scene/01/235.jpg
#  extracting: 15-Scene/15-Scene/01/236.jpg
#  extracting: 15-Scene/15-Scene/01/237.jpg
#  extracting: 15-Scene/15-Scene/01/238.jpg
#  extracting: 15-Scene/15-Scene/01/239.jpg
#   inflating: 15-Scene/15-Scene/01/240.jpg
#   inflating: 15-Scene/15-Scene/01/241.jpg
#   inflating: 15-Scene/15-Scene/01/242.jpg
#   inflating: 15-Scene/15-Scene/01/243.jpg
#  extracting: 15-Scene/15-Scene/01/244.jpg
#   inflating: 15-Scene/15-Scene/01/245.jpg
#  extracting: 15-Scene/15-Scene/01/246.jpg
#   inflating: 15-Scene/15-Scene/01/247.jpg
#   inflating: 15-Scene/15-Scene/01/248.jpg
#  extracting: 15-Scene/15-Scene/01/249.jpg
#   inflating: 15-Scene/15-Scene/01/250.jpg
#   inflating: 15-Scene/15-Scene/01/251.jpg
#  extracting: 15-Scene/15-Scene/01/252.jpg
#   inflating: 15-Scene/15-Scene/01/253.jpg
#   inflating: 15-Scene/15-Scene/01/254.jpg
#  extracting: 15-Scene/15-Scene/01/255.jpg
#   inflating: 15-Scene/15-Scene/01/256.jpg
#   inflating: 15-Scene/15-Scene/01/257.jpg
#   inflating: 15-Scene/15-Scene/01/258.jpg
#  extracting: 15-Scene/15-Scene/01/259.jpg
#  extracting: 15-Scene/15-Scene/01/260.jpg
#  extracting: 15-Scene/15-Scene/01/261.jpg
#   inflating: 15-Scene/15-Scene/01/262.jpg
#   inflating: 15-Scene/15-Scene/01/263.jpg
#   inflating: 15-Scene/15-Scene/01/264.jpg
#  extracting: 15-Scene/15-Scene/01/265.jpg
#  extracting: 15-Scene/15-Scene/01/266.jpg
#   inflating: 15-Scene/15-Scene/01/267.jpg
#  extracting: 15-Scene/15-Scene/01/268.jpg
#   inflating: 15-Scene/15-Scene/01/269.jpg
#   inflating: 15-Scene/15-Scene/01/270.jpg
#   inflating: 15-Scene/15-Scene/01/271.jpg
#   inflating: 15-Scene/15-Scene/01/272.jpg
#   inflating: 15-Scene/15-Scene/01/273.jpg
#  extracting: 15-Scene/15-Scene/01/274.jpg
#   inflating: 15-Scene/15-Scene/01/275.jpg
#   inflating: 15-Scene/15-Scene/01/276.jpg
#   inflating: 15-Scene/15-Scene/01/277.jpg
#   inflating: 15-Scene/15-Scene/01/278.jpg
#   inflating: 15-Scene/15-Scene/01/279.jpg
#   inflating: 15-Scene/15-Scene/01/280.jpg
#  extracting: 15-Scene/15-Scene/01/281.jpg
#  extracting: 15-Scene/15-Scene/01/282.jpg
#  extracting: 15-Scene/15-Scene/01/283.jpg
#   inflating: 15-Scene/15-Scene/01/284.jpg
#   inflating: 15-Scene/15-Scene/01/285.jpg
#   inflating: 15-Scene/15-Scene/01/286.jpg
#  extracting: 15-Scene/15-Scene/01/287.jpg
#   inflating: 15-Scene/15-Scene/01/288.jpg
#   inflating: 15-Scene/15-Scene/01/289.jpg
#  extracting: 15-Scene/15-Scene/01/290.jpg
#  extracting: 15-Scene/15-Scene/01/291.jpg
#  extracting: 15-Scene/15-Scene/01/292.jpg
#  extracting: 15-Scene/15-Scene/01/293.jpg
#  extracting: 15-Scene/15-Scene/01/294.jpg
#  extracting: 15-Scene/15-Scene/01/295.jpg
#  extracting: 15-Scene/15-Scene/01/296.jpg
#  extracting: 15-Scene/15-Scene/01/297.jpg
#  extracting: 15-Scene/15-Scene/01/298.jpg
#  extracting: 15-Scene/15-Scene/01/299.jpg
#  extracting: 15-Scene/15-Scene/01/300.jpg
#   inflating: 15-Scene/15-Scene/01/301.jpg
#  extracting: 15-Scene/15-Scene/01/302.jpg
#  extracting: 15-Scene/15-Scene/01/303.jpg
#  extracting: 15-Scene/15-Scene/01/304.jpg
#  extracting: 15-Scene/15-Scene/01/305.jpg
#  extracting: 15-Scene/15-Scene/01/306.jpg
#   inflating: 15-Scene/15-Scene/01/307.jpg
#  extracting: 15-Scene/15-Scene/01/308.jpg
#   inflating: 15-Scene/15-Scene/01/309.jpg
#  extracting: 15-Scene/15-Scene/01/310.jpg
#  extracting: 15-Scene/15-Scene/01/311.jpg
#  extracting: 15-Scene/15-Scene/01/312.jpg
#   inflating: 15-Scene/15-Scene/01/313.jpg
#  extracting: 15-Scene/15-Scene/01/314.jpg
#   inflating: 15-Scene/15-Scene/01/315.jpg
#  extracting: 15-Scene/15-Scene/01/316.jpg
#  extracting: 15-Scene/15-Scene/01/317.jpg
#  extracting: 15-Scene/15-Scene/01/318.jpg
#  extracting: 15-Scene/15-Scene/01/319.jpg
#  extracting: 15-Scene/15-Scene/01/320.jpg
#  extracting: 15-Scene/15-Scene/01/321.jpg
#   inflating: 15-Scene/15-Scene/01/322.jpg
#  extracting: 15-Scene/15-Scene/01/323.jpg
#  extracting: 15-Scene/15-Scene/01/324.jpg
#  extracting: 15-Scene/15-Scene/01/325.jpg
#  extracting: 15-Scene/15-Scene/01/326.jpg
#  extracting: 15-Scene/15-Scene/01/327.jpg
#  extracting: 15-Scene/15-Scene/01/328.jpg
#  extracting: 15-Scene/15-Scene/01/329.jpg
#  extracting: 15-Scene/15-Scene/01/330.jpg
#  extracting: 15-Scene/15-Scene/01/331.jpg
#  extracting: 15-Scene/15-Scene/01/332.jpg
#  extracting: 15-Scene/15-Scene/01/333.jpg
#  extracting: 15-Scene/15-Scene/01/334.jpg
#  extracting: 15-Scene/15-Scene/01/335.jpg
#   inflating: 15-Scene/15-Scene/01/336.jpg
#   inflating: 15-Scene/15-Scene/01/337.jpg
#  extracting: 15-Scene/15-Scene/01/338.jpg
#   inflating: 15-Scene/15-Scene/01/339.jpg
#  extracting: 15-Scene/15-Scene/01/340.jpg
#  extracting: 15-Scene/15-Scene/01/341.jpg
#   inflating: 15-Scene/15-Scene/01/342.jpg
#  extracting: 15-Scene/15-Scene/01/343.jpg
#   inflating: 15-Scene/15-Scene/01/344.jpg
#   inflating: 15-Scene/15-Scene/01/345.jpg
#  extracting: 15-Scene/15-Scene/01/346.jpg
#  extracting: 15-Scene/15-Scene/01/347.jpg
#  extracting: 15-Scene/15-Scene/01/348.jpg
#   inflating: 15-Scene/15-Scene/01/349.jpg
#   inflating: 15-Scene/15-Scene/01/350.jpg
#  extracting: 15-Scene/15-Scene/01/351.jpg
#   inflating: 15-Scene/15-Scene/01/352.jpg
#  extracting: 15-Scene/15-Scene/01/353.jpg
#  extracting: 15-Scene/15-Scene/01/354.jpg
#   inflating: 15-Scene/15-Scene/01/355.jpg
#  extracting: 15-Scene/15-Scene/01/356.jpg
#   inflating: 15-Scene/15-Scene/01/357.jpg
#   inflating: 15-Scene/15-Scene/01/358.jpg
#  extracting: 15-Scene/15-Scene/01/359.jpg
#  extracting: 15-Scene/15-Scene/01/360.jpg
#   inflating: 15-Scene/15-Scene/01/361.jpg
#  extracting: 15-Scene/15-Scene/01/362.jpg
#  extracting: 15-Scene/15-Scene/01/363.jpg
#   inflating: 15-Scene/15-Scene/01/364.jpg
#  extracting: 15-Scene/15-Scene/01/365.jpg
#   inflating: 15-Scene/15-Scene/01/366.jpg
#  extracting: 15-Scene/15-Scene/01/367.jpg
#  extracting: 15-Scene/15-Scene/01/368.jpg
#   inflating: 15-Scene/15-Scene/01/369.jpg
#  extracting: 15-Scene/15-Scene/01/370.jpg
#  extracting: 15-Scene/15-Scene/01/371.jpg
#  extracting: 15-Scene/15-Scene/01/372.jpg
#   inflating: 15-Scene/15-Scene/01/373.jpg
#   inflating: 15-Scene/15-Scene/01/374.jpg
#  extracting: 15-Scene/15-Scene/01/375.jpg
#   inflating: 15-Scene/15-Scene/01/376.jpg
#  extracting: 15-Scene/15-Scene/01/377.jpg
#   inflating: 15-Scene/15-Scene/01/378.jpg
#   inflating: 15-Scene/15-Scene/01/379.jpg
#  extracting: 15-Scene/15-Scene/01/380.jpg
#  extracting: 15-Scene/15-Scene/01/381.jpg
#   inflating: 15-Scene/15-Scene/01/382.jpg
#   inflating: 15-Scene/15-Scene/01/383.jpg
#   inflating: 15-Scene/15-Scene/01/384.jpg
#  extracting: 15-Scene/15-Scene/01/385.jpg
#  extracting: 15-Scene/15-Scene/01/386.jpg
#  extracting: 15-Scene/15-Scene/01/387.jpg
#   inflating: 15-Scene/15-Scene/01/388.jpg
#   inflating: 15-Scene/15-Scene/01/389.jpg
#   inflating: 15-Scene/15-Scene/01/390.jpg
#  extracting: 15-Scene/15-Scene/01/391.jpg
#  extracting: 15-Scene/15-Scene/01/392.jpg
#   inflating: 15-Scene/15-Scene/01/393.jpg
#   inflating: 15-Scene/15-Scene/01/394.jpg
#   inflating: 15-Scene/15-Scene/01/395.jpg
#  extracting: 15-Scene/15-Scene/01/396.jpg
#   inflating: 15-Scene/15-Scene/01/397.jpg
#   inflating: 15-Scene/15-Scene/01/398.jpg
#  extracting: 15-Scene/15-Scene/01/399.jpg
#   inflating: 15-Scene/15-Scene/01/400.jpg
#   inflating: 15-Scene/15-Scene/01/401.jpg
#   inflating: 15-Scene/15-Scene/01/402.jpg
#  extracting: 15-Scene/15-Scene/01/403.jpg
#   inflating: 15-Scene/15-Scene/01/404.jpg
#   inflating: 15-Scene/15-Scene/01/405.jpg
#   inflating: 15-Scene/15-Scene/01/406.jpg
#   inflating: 15-Scene/15-Scene/01/407.jpg
#  extracting: 15-Scene/15-Scene/01/408.jpg
#   inflating: 15-Scene/15-Scene/01/409.jpg
#   inflating: 15-Scene/15-Scene/01/410.jpg
#  extracting: 15-Scene/15-Scene/01/411.jpg
#   inflating: 15-Scene/15-Scene/01/412.jpg
#   inflating: 15-Scene/15-Scene/01/413.jpg
#   inflating: 15-Scene/15-Scene/01/414.jpg
#   inflating: 15-Scene/15-Scene/01/415.jpg
#   inflating: 15-Scene/15-Scene/01/416.jpg
#   inflating: 15-Scene/15-Scene/01/417.jpg
#  extracting: 15-Scene/15-Scene/01/418.jpg
#  extracting: 15-Scene/15-Scene/01/419.jpg
#  extracting: 15-Scene/15-Scene/01/420.jpg
#  extracting: 15-Scene/15-Scene/01/421.jpg
#  extracting: 15-Scene/15-Scene/01/422.jpg
#   inflating: 15-Scene/15-Scene/01/423.jpg
#   inflating: 15-Scene/15-Scene/01/424.jpg
#   inflating: 15-Scene/15-Scene/01/425.jpg
#   inflating: 15-Scene/15-Scene/01/426.jpg
#   inflating: 15-Scene/15-Scene/01/427.jpg
#   inflating: 15-Scene/15-Scene/01/428.jpg
#  extracting: 15-Scene/15-Scene/01/429.jpg
#  extracting: 15-Scene/15-Scene/01/430.jpg
#  extracting: 15-Scene/15-Scene/01/431.jpg
#   inflating: 15-Scene/15-Scene/01/432.jpg
#   inflating: 15-Scene/15-Scene/01/433.jpg
#   inflating: 15-Scene/15-Scene/01/434.jpg
#  extracting: 15-Scene/15-Scene/01/435.jpg
#   inflating: 15-Scene/15-Scene/01/436.jpg
#   inflating: 15-Scene/15-Scene/01/437.jpg
#   inflating: 15-Scene/15-Scene/01/438.jpg
#   inflating: 15-Scene/15-Scene/01/439.jpg
#   inflating: 15-Scene/15-Scene/01/440.jpg
#   inflating: 15-Scene/15-Scene/01/441.jpg
#  extracting: 15-Scene/15-Scene/01/442.jpg
#   inflating: 15-Scene/15-Scene/01/443.jpg
#   inflating: 15-Scene/15-Scene/01/444.jpg
#   inflating: 15-Scene/15-Scene/01/445.jpg
#   inflating: 15-Scene/15-Scene/01/446.jpg
#   inflating: 15-Scene/15-Scene/01/447.jpg
#  extracting: 15-Scene/15-Scene/01/448.jpg
#   inflating: 15-Scene/15-Scene/01/449.jpg
#  extracting: 15-Scene/15-Scene/01/450.jpg
#   inflating: 15-Scene/15-Scene/01/451.jpg
#  extracting: 15-Scene/15-Scene/01/452.jpg
#   inflating: 15-Scene/15-Scene/01/453.jpg
#   inflating: 15-Scene/15-Scene/01/454.jpg
#  extracting: 15-Scene/15-Scene/01/455.jpg
#   inflating: 15-Scene/15-Scene/01/456.jpg
#  extracting: 15-Scene/15-Scene/01/457.jpg
#    creating: 15-Scene/15-Scene/02/
#   inflating: 15-Scene/15-Scene/02/458.jpg
#   inflating: 15-Scene/15-Scene/02/459.jpg
#   inflating: 15-Scene/15-Scene/02/460.jpg
#   inflating: 15-Scene/15-Scene/02/461.jpg
#   inflating: 15-Scene/15-Scene/02/462.jpg
#   inflating: 15-Scene/15-Scene/02/463.jpg
#   inflating: 15-Scene/15-Scene/02/464.jpg
#   inflating: 15-Scene/15-Scene/02/465.jpg
#   inflating: 15-Scene/15-Scene/02/466.jpg
#   inflating: 15-Scene/15-Scene/02/467.jpg
#   inflating: 15-Scene/15-Scene/02/468.jpg
#   inflating: 15-Scene/15-Scene/02/469.jpg
#   inflating: 15-Scene/15-Scene/02/470.jpg
#   inflating: 15-Scene/15-Scene/02/471.jpg
#   inflating: 15-Scene/15-Scene/02/472.jpg
#   inflating: 15-Scene/15-Scene/02/473.jpg
#   inflating: 15-Scene/15-Scene/02/474.jpg
#   inflating: 15-Scene/15-Scene/02/475.jpg
#   inflating: 15-Scene/15-Scene/02/476.jpg
#   inflating: 15-Scene/15-Scene/02/477.jpg
#   inflating: 15-Scene/15-Scene/02/478.jpg
#   inflating: 15-Scene/15-Scene/02/479.jpg
#   inflating: 15-Scene/15-Scene/02/480.jpg
#   inflating: 15-Scene/15-Scene/02/481.jpg
#   inflating: 15-Scene/15-Scene/02/482.jpg
#   inflating: 15-Scene/15-Scene/02/483.jpg
#   inflating: 15-Scene/15-Scene/02/484.jpg
#   inflating: 15-Scene/15-Scene/02/485.jpg
#   inflating: 15-Scene/15-Scene/02/486.jpg
#   inflating: 15-Scene/15-Scene/02/487.jpg
#   inflating: 15-Scene/15-Scene/02/488.jpg
#   inflating: 15-Scene/15-Scene/02/489.jpg
#   inflating: 15-Scene/15-Scene/02/490.jpg
#   inflating: 15-Scene/15-Scene/02/491.jpg
#   inflating: 15-Scene/15-Scene/02/492.jpg
#   inflating: 15-Scene/15-Scene/02/493.jpg
#   inflating: 15-Scene/15-Scene/02/494.jpg
#   inflating: 15-Scene/15-Scene/02/495.jpg
#   inflating: 15-Scene/15-Scene/02/496.jpg
#   inflating: 15-Scene/15-Scene/02/497.jpg
#   inflating: 15-Scene/15-Scene/02/498.jpg
#   inflating: 15-Scene/15-Scene/02/499.jpg
#   inflating: 15-Scene/15-Scene/02/500.jpg
#   inflating: 15-Scene/15-Scene/02/501.jpg
#   inflating: 15-Scene/15-Scene/02/502.jpg
#   inflating: 15-Scene/15-Scene/02/503.jpg
#   inflating: 15-Scene/15-Scene/02/504.jpg
#   inflating: 15-Scene/15-Scene/02/505.jpg
#   inflating: 15-Scene/15-Scene/02/506.jpg
#   inflating: 15-Scene/15-Scene/02/507.jpg
#   inflating: 15-Scene/15-Scene/02/508.jpg
#   inflating: 15-Scene/15-Scene/02/509.jpg
#   inflating: 15-Scene/15-Scene/02/510.jpg
#   inflating: 15-Scene/15-Scene/02/511.jpg
#   inflating: 15-Scene/15-Scene/02/512.jpg
#   inflating: 15-Scene/15-Scene/02/513.jpg
#   inflating: 15-Scene/15-Scene/02/514.jpg
#   inflating: 15-Scene/15-Scene/02/515.jpg
#   inflating: 15-Scene/15-Scene/02/516.jpg
#   inflating: 15-Scene/15-Scene/02/517.jpg
#   inflating: 15-Scene/15-Scene/02/518.jpg
#   inflating: 15-Scene/15-Scene/02/519.jpg
#   inflating: 15-Scene/15-Scene/02/520.jpg
#   inflating: 15-Scene/15-Scene/02/521.jpg
#   inflating: 15-Scene/15-Scene/02/522.jpg
#   inflating: 15-Scene/15-Scene/02/523.jpg
#   inflating: 15-Scene/15-Scene/02/524.jpg
#   inflating: 15-Scene/15-Scene/02/525.jpg
#   inflating: 15-Scene/15-Scene/02/526.jpg
#   inflating: 15-Scene/15-Scene/02/527.jpg
#   inflating: 15-Scene/15-Scene/02/528.jpg
#   inflating: 15-Scene/15-Scene/02/529.jpg
#   inflating: 15-Scene/15-Scene/02/530.jpg
#   inflating: 15-Scene/15-Scene/02/531.jpg
#   inflating: 15-Scene/15-Scene/02/532.jpg
#   inflating: 15-Scene/15-Scene/02/533.jpg
#   inflating: 15-Scene/15-Scene/02/534.jpg
#   inflating: 15-Scene/15-Scene/02/535.jpg
#   inflating: 15-Scene/15-Scene/02/536.jpg
#   inflating: 15-Scene/15-Scene/02/537.jpg
#   inflating: 15-Scene/15-Scene/02/538.jpg
#   inflating: 15-Scene/15-Scene/02/539.jpg
#   inflating: 15-Scene/15-Scene/02/540.jpg
#   inflating: 15-Scene/15-Scene/02/541.jpg
#   inflating: 15-Scene/15-Scene/02/542.jpg
#   inflating: 15-Scene/15-Scene/02/543.jpg
#   inflating: 15-Scene/15-Scene/02/544.jpg
#   inflating: 15-Scene/15-Scene/02/545.jpg
#   inflating: 15-Scene/15-Scene/02/546.jpg
#   inflating: 15-Scene/15-Scene/02/547.jpg
#   inflating: 15-Scene/15-Scene/02/548.jpg
#   inflating: 15-Scene/15-Scene/02/549.jpg
#   inflating: 15-Scene/15-Scene/02/550.jpg
#   inflating: 15-Scene/15-Scene/02/551.jpg
#   inflating: 15-Scene/15-Scene/02/552.jpg
#   inflating: 15-Scene/15-Scene/02/553.jpg
#   inflating: 15-Scene/15-Scene/02/554.jpg
#   inflating: 15-Scene/15-Scene/02/555.jpg
#   inflating: 15-Scene/15-Scene/02/556.jpg
#   inflating: 15-Scene/15-Scene/02/557.jpg
#   inflating: 15-Scene/15-Scene/02/558.jpg
#   inflating: 15-Scene/15-Scene/02/559.jpg
#   inflating: 15-Scene/15-Scene/02/560.jpg
#   inflating: 15-Scene/15-Scene/02/561.jpg
#   inflating: 15-Scene/15-Scene/02/562.jpg
#   inflating: 15-Scene/15-Scene/02/563.jpg
#   inflating: 15-Scene/15-Scene/02/564.jpg
#   inflating: 15-Scene/15-Scene/02/565.jpg
#   inflating: 15-Scene/15-Scene/02/566.jpg
#   inflating: 15-Scene/15-Scene/02/567.jpg
#   inflating: 15-Scene/15-Scene/02/568.jpg
#   inflating: 15-Scene/15-Scene/02/569.jpg
#   inflating: 15-Scene/15-Scene/02/570.jpg
#   inflating: 15-Scene/15-Scene/02/571.jpg
#   inflating: 15-Scene/15-Scene/02/572.jpg
#   inflating: 15-Scene/15-Scene/02/573.jpg
#   inflating: 15-Scene/15-Scene/02/574.jpg
#   inflating: 15-Scene/15-Scene/02/575.jpg
#   inflating: 15-Scene/15-Scene/02/576.jpg
#   inflating: 15-Scene/15-Scene/02/577.jpg
#   inflating: 15-Scene/15-Scene/02/578.jpg
#   inflating: 15-Scene/15-Scene/02/579.jpg
#   inflating: 15-Scene/15-Scene/02/580.jpg
#   inflating: 15-Scene/15-Scene/02/581.jpg
#   inflating: 15-Scene/15-Scene/02/582.jpg
#   inflating: 15-Scene/15-Scene/02/583.jpg
#   inflating: 15-Scene/15-Scene/02/584.jpg
#   inflating: 15-Scene/15-Scene/02/585.jpg
#   inflating: 15-Scene/15-Scene/02/586.jpg
#   inflating: 15-Scene/15-Scene/02/587.jpg
#   inflating: 15-Scene/15-Scene/02/588.jpg
#   inflating: 15-Scene/15-Scene/02/589.jpg
#   inflating: 15-Scene/15-Scene/02/590.jpg
#   inflating: 15-Scene/15-Scene/02/591.jpg
#   inflating: 15-Scene/15-Scene/02/592.jpg
#   inflating: 15-Scene/15-Scene/02/593.jpg
#   inflating: 15-Scene/15-Scene/02/594.jpg
#   inflating: 15-Scene/15-Scene/02/595.jpg
#   inflating: 15-Scene/15-Scene/02/596.jpg
#   inflating: 15-Scene/15-Scene/02/597.jpg
#   inflating: 15-Scene/15-Scene/02/598.jpg
#   inflating: 15-Scene/15-Scene/02/599.jpg
#   inflating: 15-Scene/15-Scene/02/600.jpg
#   inflating: 15-Scene/15-Scene/02/601.jpg
#   inflating: 15-Scene/15-Scene/02/602.jpg
#   inflating: 15-Scene/15-Scene/02/603.jpg
#   inflating: 15-Scene/15-Scene/02/604.jpg
#   inflating: 15-Scene/15-Scene/02/605.jpg
#   inflating: 15-Scene/15-Scene/02/606.jpg
#   inflating: 15-Scene/15-Scene/02/607.jpg
#   inflating: 15-Scene/15-Scene/02/608.jpg
#   inflating: 15-Scene/15-Scene/02/609.jpg
#   inflating: 15-Scene/15-Scene/02/610.jpg
#   inflating: 15-Scene/15-Scene/02/611.jpg
#   inflating: 15-Scene/15-Scene/02/612.jpg
#   inflating: 15-Scene/15-Scene/02/613.jpg
#   inflating: 15-Scene/15-Scene/02/614.jpg
#   inflating: 15-Scene/15-Scene/02/615.jpg
#   inflating: 15-Scene/15-Scene/02/616.jpg
#   inflating: 15-Scene/15-Scene/02/617.jpg
#   inflating: 15-Scene/15-Scene/02/618.jpg
#   inflating: 15-Scene/15-Scene/02/619.jpg
#   inflating: 15-Scene/15-Scene/02/620.jpg
#   inflating: 15-Scene/15-Scene/02/621.jpg
#   inflating: 15-Scene/15-Scene/02/622.jpg
#   inflating: 15-Scene/15-Scene/02/623.jpg
#   inflating: 15-Scene/15-Scene/02/624.jpg
#   inflating: 15-Scene/15-Scene/02/625.jpg
#   inflating: 15-Scene/15-Scene/02/626.jpg
#   inflating: 15-Scene/15-Scene/02/627.jpg
#   inflating: 15-Scene/15-Scene/02/628.jpg
#   inflating: 15-Scene/15-Scene/02/629.jpg
#   inflating: 15-Scene/15-Scene/02/630.jpg
#   inflating: 15-Scene/15-Scene/02/631.jpg
#   inflating: 15-Scene/15-Scene/02/633.jpg
#   inflating: 15-Scene/15-Scene/02/634.jpg
#   inflating: 15-Scene/15-Scene/02/635.jpg
#   inflating: 15-Scene/15-Scene/02/636.jpg
#   inflating: 15-Scene/15-Scene/02/637.jpg
#   inflating: 15-Scene/15-Scene/02/638.jpg
#   inflating: 15-Scene/15-Scene/02/639.jpg
#   inflating: 15-Scene/15-Scene/02/640.jpg
#   inflating: 15-Scene/15-Scene/02/641.jpg
#   inflating: 15-Scene/15-Scene/02/642.jpg
#   inflating: 15-Scene/15-Scene/02/643.jpg
#   inflating: 15-Scene/15-Scene/02/644.jpg
#   inflating: 15-Scene/15-Scene/02/645.jpg
#   inflating: 15-Scene/15-Scene/02/646.jpg
#   inflating: 15-Scene/15-Scene/02/647.jpg
#   inflating: 15-Scene/15-Scene/02/648.jpg
#   inflating: 15-Scene/15-Scene/02/649.jpg
#   inflating: 15-Scene/15-Scene/02/650.jpg
#   inflating: 15-Scene/15-Scene/02/651.jpg
#   inflating: 15-Scene/15-Scene/02/652.jpg
#   inflating: 15-Scene/15-Scene/02/653.jpg
#   inflating: 15-Scene/15-Scene/02/654.jpg
#   inflating: 15-Scene/15-Scene/02/655.jpg
#   inflating: 15-Scene/15-Scene/02/656.jpg
#   inflating: 15-Scene/15-Scene/02/657.jpg
#   inflating: 15-Scene/15-Scene/02/658.jpg
#   inflating: 15-Scene/15-Scene/02/659.jpg
#   inflating: 15-Scene/15-Scene/02/660.jpg
#   inflating: 15-Scene/15-Scene/02/661.jpg
#   inflating: 15-Scene/15-Scene/02/662.jpg
#   inflating: 15-Scene/15-Scene/02/663.jpg
#   inflating: 15-Scene/15-Scene/02/664.jpg
#   inflating: 15-Scene/15-Scene/02/665.jpg
#   inflating: 15-Scene/15-Scene/02/666.jpg
#   inflating: 15-Scene/15-Scene/02/667.jpg
#   inflating: 15-Scene/15-Scene/02/668.jpg
#   inflating: 15-Scene/15-Scene/02/669.jpg
#   inflating: 15-Scene/15-Scene/02/670.jpg
#   inflating: 15-Scene/15-Scene/02/671.jpg
#   inflating: 15-Scene/15-Scene/02/672.jpg
#   inflating: 15-Scene/15-Scene/02/673.jpg
#   inflating: 15-Scene/15-Scene/02/674.jpg
#   inflating: 15-Scene/15-Scene/02/675.jpg
#   inflating: 15-Scene/15-Scene/02/676.jpg
#   inflating: 15-Scene/15-Scene/02/677.jpg
#   inflating: 15-Scene/15-Scene/02/678.jpg
#   inflating: 15-Scene/15-Scene/02/679.jpg
#   inflating: 15-Scene/15-Scene/02/680.jpg
#   inflating: 15-Scene/15-Scene/02/681.jpg
#   inflating: 15-Scene/15-Scene/02/682.jpg
#   inflating: 15-Scene/15-Scene/02/683.jpg
#   inflating: 15-Scene/15-Scene/02/684.jpg
#   inflating: 15-Scene/15-Scene/02/685.jpg
#   inflating: 15-Scene/15-Scene/02/686.jpg
#   inflating: 15-Scene/15-Scene/02/687.jpg
#   inflating: 15-Scene/15-Scene/02/688.jpg
#   inflating: 15-Scene/15-Scene/02/689.jpg
#   inflating: 15-Scene/15-Scene/02/690.jpg
#   inflating: 15-Scene/15-Scene/02/691.jpg
#   inflating: 15-Scene/15-Scene/02/692.jpg
#   inflating: 15-Scene/15-Scene/02/693.jpg
#   inflating: 15-Scene/15-Scene/02/694.jpg
#   inflating: 15-Scene/15-Scene/02/695.jpg
#   inflating: 15-Scene/15-Scene/02/696.jpg
#   inflating: 15-Scene/15-Scene/02/697.jpg
#   inflating: 15-Scene/15-Scene/02/698.jpg
#   inflating: 15-Scene/15-Scene/02/699.jpg
#   inflating: 15-Scene/15-Scene/02/700.jpg
#   inflating: 15-Scene/15-Scene/02/701.jpg
#   inflating: 15-Scene/15-Scene/02/702.jpg
#   inflating: 15-Scene/15-Scene/02/703.jpg
#   inflating: 15-Scene/15-Scene/02/704.jpg
#   inflating: 15-Scene/15-Scene/02/705.jpg
#   inflating: 15-Scene/15-Scene/02/706.jpg
#   inflating: 15-Scene/15-Scene/02/707.jpg
#   inflating: 15-Scene/15-Scene/02/708.jpg
#   inflating: 15-Scene/15-Scene/02/709.jpg
#   inflating: 15-Scene/15-Scene/02/710.jpg
#   inflating: 15-Scene/15-Scene/02/711.jpg
#   inflating: 15-Scene/15-Scene/02/712.jpg
#   inflating: 15-Scene/15-Scene/02/713.jpg
#   inflating: 15-Scene/15-Scene/02/714.jpg
#   inflating: 15-Scene/15-Scene/02/715.jpg
#   inflating: 15-Scene/15-Scene/02/716.jpg
#   inflating: 15-Scene/15-Scene/02/717.jpg
#   inflating: 15-Scene/15-Scene/02/718.jpg
#   inflating: 15-Scene/15-Scene/02/719.jpg
#   inflating: 15-Scene/15-Scene/02/720.jpg
#   inflating: 15-Scene/15-Scene/02/721.jpg
#   inflating: 15-Scene/15-Scene/02/722.jpg
#   inflating: 15-Scene/15-Scene/02/723.jpg
#   inflating: 15-Scene/15-Scene/02/725.jpg
#   inflating: 15-Scene/15-Scene/02/726.jpg
#   inflating: 15-Scene/15-Scene/02/727.jpg
#   inflating: 15-Scene/15-Scene/02/728.jpg
#   inflating: 15-Scene/15-Scene/02/729.jpg
#   inflating: 15-Scene/15-Scene/02/730.jpg
#   inflating: 15-Scene/15-Scene/02/731.jpg
#   inflating: 15-Scene/15-Scene/02/732.jpg
#   inflating: 15-Scene/15-Scene/02/733.jpg
#   inflating: 15-Scene/15-Scene/02/734.jpg
#   inflating: 15-Scene/15-Scene/02/735.jpg
#   inflating: 15-Scene/15-Scene/02/736.jpg
#   inflating: 15-Scene/15-Scene/02/737.jpg
#   inflating: 15-Scene/15-Scene/02/738.jpg
#   inflating: 15-Scene/15-Scene/02/740.jpg
#   inflating: 15-Scene/15-Scene/02/741.jpg
#   inflating: 15-Scene/15-Scene/02/742.jpg
#   inflating: 15-Scene/15-Scene/02/743.jpg
#   inflating: 15-Scene/15-Scene/02/744.jpg
#   inflating: 15-Scene/15-Scene/02/745.jpg
#   inflating: 15-Scene/15-Scene/02/746.jpg
#   inflating: 15-Scene/15-Scene/02/747.jpg
#   inflating: 15-Scene/15-Scene/02/748.jpg
#   inflating: 15-Scene/15-Scene/02/749.jpg
#   inflating: 15-Scene/15-Scene/02/750.jpg
#   inflating: 15-Scene/15-Scene/02/751.jpg
#   inflating: 15-Scene/15-Scene/02/752.jpg
#   inflating: 15-Scene/15-Scene/02/753.jpg
#   inflating: 15-Scene/15-Scene/02/754.jpg
#   inflating: 15-Scene/15-Scene/02/755.jpg
#   inflating: 15-Scene/15-Scene/02/756.jpg
#   inflating: 15-Scene/15-Scene/02/757.jpg
#   inflating: 15-Scene/15-Scene/02/758.jpg
#   inflating: 15-Scene/15-Scene/02/759.jpg
#   inflating: 15-Scene/15-Scene/02/760.jpg
#   inflating: 15-Scene/15-Scene/02/761.jpg
#   inflating: 15-Scene/15-Scene/02/762.jpg
#   inflating: 15-Scene/15-Scene/02/763.jpg
#   inflating: 15-Scene/15-Scene/02/764.jpg
#   inflating: 15-Scene/15-Scene/02/765.jpg
#   inflating: 15-Scene/15-Scene/02/766.jpg
#   inflating: 15-Scene/15-Scene/02/767.jpg
#   inflating: 15-Scene/15-Scene/02/768.jpg
#    creating: 15-Scene/15-Scene/03/
#  extracting: 15-Scene/15-Scene/03/769.jpg
#   inflating: 15-Scene/15-Scene/03/770.jpg
#  extracting: 15-Scene/15-Scene/03/771.jpg
#   inflating: 15-Scene/15-Scene/03/772.jpg
#  extracting: 15-Scene/15-Scene/03/773.jpg
#  extracting: 15-Scene/15-Scene/03/774.jpg
#   inflating: 15-Scene/15-Scene/03/775.jpg
#  extracting: 15-Scene/15-Scene/03/776.jpg
#  extracting: 15-Scene/15-Scene/03/777.jpg
#  extracting: 15-Scene/15-Scene/03/778.jpg
#  extracting: 15-Scene/15-Scene/03/779.jpg
#  extracting: 15-Scene/15-Scene/03/780.jpg
#   inflating: 15-Scene/15-Scene/03/781.jpg
#  extracting: 15-Scene/15-Scene/03/782.jpg
#   inflating: 15-Scene/15-Scene/03/783.jpg
#  extracting: 15-Scene/15-Scene/03/784.jpg
#  extracting: 15-Scene/15-Scene/03/785.jpg
#  extracting: 15-Scene/15-Scene/03/786.jpg
#  extracting: 15-Scene/15-Scene/03/787.jpg
#  extracting: 15-Scene/15-Scene/03/788.jpg
#  extracting: 15-Scene/15-Scene/03/789.jpg
#  extracting: 15-Scene/15-Scene/03/790.jpg
#  extracting: 15-Scene/15-Scene/03/791.jpg
#  extracting: 15-Scene/15-Scene/03/792.jpg
#  extracting: 15-Scene/15-Scene/03/793.jpg
#  extracting: 15-Scene/15-Scene/03/794.jpg
#  extracting: 15-Scene/15-Scene/03/795.jpg
#  extracting: 15-Scene/15-Scene/03/796.jpg
#  extracting: 15-Scene/15-Scene/03/797.jpg
#  extracting: 15-Scene/15-Scene/03/798.jpg
#   inflating: 15-Scene/15-Scene/03/799.jpg
#   inflating: 15-Scene/15-Scene/03/800.jpg
#  extracting: 15-Scene/15-Scene/03/801.jpg
#  extracting: 15-Scene/15-Scene/03/802.jpg
#  extracting: 15-Scene/15-Scene/03/803.jpg
#  extracting: 15-Scene/15-Scene/03/804.jpg
#  extracting: 15-Scene/15-Scene/03/805.jpg
#   inflating: 15-Scene/15-Scene/03/806.jpg
#  extracting: 15-Scene/15-Scene/03/807.jpg
#  extracting: 15-Scene/15-Scene/03/808.jpg
#  extracting: 15-Scene/15-Scene/03/809.jpg
#  extracting: 15-Scene/15-Scene/03/810.jpg
#  extracting: 15-Scene/15-Scene/03/811.jpg
#  extracting: 15-Scene/15-Scene/03/812.jpg
#  extracting: 15-Scene/15-Scene/03/813.jpg
#   inflating: 15-Scene/15-Scene/03/814.jpg
#   inflating: 15-Scene/15-Scene/03/815.jpg
#   inflating: 15-Scene/15-Scene/03/816.jpg
#   inflating: 15-Scene/15-Scene/03/817.jpg
#   inflating: 15-Scene/15-Scene/03/818.jpg
#   inflating: 15-Scene/15-Scene/03/819.jpg
#   inflating: 15-Scene/15-Scene/03/820.jpg
#   inflating: 15-Scene/15-Scene/03/821.jpg
#   inflating: 15-Scene/15-Scene/03/822.jpg
#   inflating: 15-Scene/15-Scene/03/823.jpg
#   inflating: 15-Scene/15-Scene/03/824.jpg
#   inflating: 15-Scene/15-Scene/03/825.jpg
#   inflating: 15-Scene/15-Scene/03/826.jpg
#   inflating: 15-Scene/15-Scene/03/827.jpg
#   inflating: 15-Scene/15-Scene/03/828.jpg
#   inflating: 15-Scene/15-Scene/03/829.jpg
#   inflating: 15-Scene/15-Scene/03/830.jpg
#   inflating: 15-Scene/15-Scene/03/831.jpg
#   inflating: 15-Scene/15-Scene/03/832.jpg
#   inflating: 15-Scene/15-Scene/03/833.jpg
#   inflating: 15-Scene/15-Scene/03/834.jpg
#   inflating: 15-Scene/15-Scene/03/835.jpg
#   inflating: 15-Scene/15-Scene/03/836.jpg
#   inflating: 15-Scene/15-Scene/03/837.jpg
#   inflating: 15-Scene/15-Scene/03/838.jpg
#   inflating: 15-Scene/15-Scene/03/839.jpg
#   inflating: 15-Scene/15-Scene/03/840.jpg
#   inflating: 15-Scene/15-Scene/03/841.jpg
#   inflating: 15-Scene/15-Scene/03/842.jpg
#   inflating: 15-Scene/15-Scene/03/843.jpg
#   inflating: 15-Scene/15-Scene/03/844.jpg
#   inflating: 15-Scene/15-Scene/03/845.jpg
#   inflating: 15-Scene/15-Scene/03/846.jpg
#   inflating: 15-Scene/15-Scene/03/847.jpg
#   inflating: 15-Scene/15-Scene/03/848.jpg
#   inflating: 15-Scene/15-Scene/03/849.jpg
#   inflating: 15-Scene/15-Scene/03/850.jpg
#   inflating: 15-Scene/15-Scene/03/851.jpg
#   inflating: 15-Scene/15-Scene/03/852.jpg
#   inflating: 15-Scene/15-Scene/03/853.jpg
#   inflating: 15-Scene/15-Scene/03/854.jpg
#   inflating: 15-Scene/15-Scene/03/855.jpg
#   inflating: 15-Scene/15-Scene/03/856.jpg
#   inflating: 15-Scene/15-Scene/03/857.jpg
#   inflating: 15-Scene/15-Scene/03/858.jpg
#   inflating: 15-Scene/15-Scene/03/859.jpg
#   inflating: 15-Scene/15-Scene/03/860.jpg
#   inflating: 15-Scene/15-Scene/03/861.jpg
#   inflating: 15-Scene/15-Scene/03/862.jpg
#   inflating: 15-Scene/15-Scene/03/863.jpg
#   inflating: 15-Scene/15-Scene/03/864.jpg
#   inflating: 15-Scene/15-Scene/03/865.jpg
#   inflating: 15-Scene/15-Scene/03/866.jpg
#   inflating: 15-Scene/15-Scene/03/867.jpg
#   inflating: 15-Scene/15-Scene/03/868.jpg
#   inflating: 15-Scene/15-Scene/03/869.jpg
#   inflating: 15-Scene/15-Scene/03/870.jpg
#   inflating: 15-Scene/15-Scene/03/871.jpg
#   inflating: 15-Scene/15-Scene/03/872.jpg
#   inflating: 15-Scene/15-Scene/03/873.jpg
#   inflating: 15-Scene/15-Scene/03/874.jpg
#   inflating: 15-Scene/15-Scene/03/875.jpg
#   inflating: 15-Scene/15-Scene/03/876.jpg
#   inflating: 15-Scene/15-Scene/03/877.jpg
#   inflating: 15-Scene/15-Scene/03/878.jpg
#   inflating: 15-Scene/15-Scene/03/879.jpg
#   inflating: 15-Scene/15-Scene/03/880.jpg
#   inflating: 15-Scene/15-Scene/03/881.jpg
#   inflating: 15-Scene/15-Scene/03/882.jpg
#   inflating: 15-Scene/15-Scene/03/883.jpg
#   inflating: 15-Scene/15-Scene/03/884.jpg
#   inflating: 15-Scene/15-Scene/03/885.jpg
#   inflating: 15-Scene/15-Scene/03/886.jpg
#   inflating: 15-Scene/15-Scene/03/887.jpg
#   inflating: 15-Scene/15-Scene/03/888.jpg
#   inflating: 15-Scene/15-Scene/03/889.jpg
#   inflating: 15-Scene/15-Scene/03/890.jpg
#   inflating: 15-Scene/15-Scene/03/891.jpg
#   inflating: 15-Scene/15-Scene/03/892.jpg
#   inflating: 15-Scene/15-Scene/03/893.jpg
#   inflating: 15-Scene/15-Scene/03/894.jpg
#   inflating: 15-Scene/15-Scene/03/895.jpg
#   inflating: 15-Scene/15-Scene/03/896.jpg
#   inflating: 15-Scene/15-Scene/03/897.jpg
#   inflating: 15-Scene/15-Scene/03/898.jpg
#   inflating: 15-Scene/15-Scene/03/899.jpg
#   inflating: 15-Scene/15-Scene/03/900.jpg
#   inflating: 15-Scene/15-Scene/03/901.jpg
#   inflating: 15-Scene/15-Scene/03/902.jpg
#   inflating: 15-Scene/15-Scene/03/903.jpg
#   inflating: 15-Scene/15-Scene/03/904.jpg
#   inflating: 15-Scene/15-Scene/03/905.jpg
#   inflating: 15-Scene/15-Scene/03/906.jpg
#   inflating: 15-Scene/15-Scene/03/907.jpg
#   inflating: 15-Scene/15-Scene/03/908.jpg
#   inflating: 15-Scene/15-Scene/03/909.jpg
#   inflating: 15-Scene/15-Scene/03/910.jpg
#   inflating: 15-Scene/15-Scene/03/911.jpg
#   inflating: 15-Scene/15-Scene/03/912.jpg
#   inflating: 15-Scene/15-Scene/03/913.jpg
#   inflating: 15-Scene/15-Scene/03/914.jpg
#   inflating: 15-Scene/15-Scene/03/915.jpg
#   inflating: 15-Scene/15-Scene/03/916.jpg
#   inflating: 15-Scene/15-Scene/03/917.jpg
#   inflating: 15-Scene/15-Scene/03/918.jpg
#   inflating: 15-Scene/15-Scene/03/919.jpg
#   inflating: 15-Scene/15-Scene/03/920.jpg
#   inflating: 15-Scene/15-Scene/03/921.jpg
#   inflating: 15-Scene/15-Scene/03/922.jpg
#   inflating: 15-Scene/15-Scene/03/923.jpg
#   inflating: 15-Scene/15-Scene/03/924.jpg
#   inflating: 15-Scene/15-Scene/03/925.jpg
#   inflating: 15-Scene/15-Scene/03/926.jpg
#   inflating: 15-Scene/15-Scene/03/927.jpg
#   inflating: 15-Scene/15-Scene/03/928.jpg
#   inflating: 15-Scene/15-Scene/03/929.jpg
#   inflating: 15-Scene/15-Scene/03/930.jpg
#   inflating: 15-Scene/15-Scene/03/931.jpg
#   inflating: 15-Scene/15-Scene/03/932.jpg
#   inflating: 15-Scene/15-Scene/03/933.jpg
#   inflating: 15-Scene/15-Scene/03/934.jpg
#   inflating: 15-Scene/15-Scene/03/935.jpg
#   inflating: 15-Scene/15-Scene/03/936.jpg
#   inflating: 15-Scene/15-Scene/03/937.jpg
#   inflating: 15-Scene/15-Scene/03/938.jpg
#   inflating: 15-Scene/15-Scene/03/939.jpg
#   inflating: 15-Scene/15-Scene/03/940.jpg
#   inflating: 15-Scene/15-Scene/03/941.jpg
#   inflating: 15-Scene/15-Scene/03/942.jpg
#   inflating: 15-Scene/15-Scene/03/943.jpg
#   inflating: 15-Scene/15-Scene/03/944.jpg
#   inflating: 15-Scene/15-Scene/03/945.jpg
#   inflating: 15-Scene/15-Scene/03/946.jpg
#   inflating: 15-Scene/15-Scene/03/947.jpg
#   inflating: 15-Scene/15-Scene/03/948.jpg
#   inflating: 15-Scene/15-Scene/03/949.jpg
#   inflating: 15-Scene/15-Scene/03/950.jpg
#   inflating: 15-Scene/15-Scene/03/951.jpg
#   inflating: 15-Scene/15-Scene/03/952.jpg
#   inflating: 15-Scene/15-Scene/03/953.jpg
#   inflating: 15-Scene/15-Scene/03/954.jpg
#   inflating: 15-Scene/15-Scene/03/955.jpg
#   inflating: 15-Scene/15-Scene/03/956.jpg
#   inflating: 15-Scene/15-Scene/03/957.jpg
#   inflating: 15-Scene/15-Scene/03/958.jpg
#   inflating: 15-Scene/15-Scene/03/959.jpg
#   inflating: 15-Scene/15-Scene/03/960.jpg
#   inflating: 15-Scene/15-Scene/03/961.jpg
#   inflating: 15-Scene/15-Scene/03/962.jpg
#   inflating: 15-Scene/15-Scene/03/963.jpg
#   inflating: 15-Scene/15-Scene/03/964.jpg
#   inflating: 15-Scene/15-Scene/03/965.jpg
#   inflating: 15-Scene/15-Scene/03/966.jpg
#   inflating: 15-Scene/15-Scene/03/967.jpg
#   inflating: 15-Scene/15-Scene/03/968.jpg
#   inflating: 15-Scene/15-Scene/03/969.jpg
#   inflating: 15-Scene/15-Scene/03/970.jpg
#   inflating: 15-Scene/15-Scene/03/971.jpg
#   inflating: 15-Scene/15-Scene/03/972.jpg
#   inflating: 15-Scene/15-Scene/03/973.jpg
#   inflating: 15-Scene/15-Scene/03/974.jpg
#   inflating: 15-Scene/15-Scene/03/975.jpg
#   inflating: 15-Scene/15-Scene/03/976.jpg
#   inflating: 15-Scene/15-Scene/03/977.jpg
#   inflating: 15-Scene/15-Scene/03/978.jpg
#    creating: 15-Scene/15-Scene/04/
#  extracting: 15-Scene/15-Scene/04/1000.jpg
#  extracting: 15-Scene/15-Scene/04/1001.jpg
#  extracting: 15-Scene/15-Scene/04/1002.jpg
#  extracting: 15-Scene/15-Scene/04/1003.jpg
#  extracting: 15-Scene/15-Scene/04/1004.jpg
#  extracting: 15-Scene/15-Scene/04/1005.jpg
#  extracting: 15-Scene/15-Scene/04/1006.jpg
#  extracting: 15-Scene/15-Scene/04/1007.jpg
#  extracting: 15-Scene/15-Scene/04/1008.jpg
#  extracting: 15-Scene/15-Scene/04/1009.jpg
#  extracting: 15-Scene/15-Scene/04/1010.jpg
#  extracting: 15-Scene/15-Scene/04/1011.jpg
#   inflating: 15-Scene/15-Scene/04/1012.jpg
#  extracting: 15-Scene/15-Scene/04/1013.jpg
#  extracting: 15-Scene/15-Scene/04/1014.jpg
#  extracting: 15-Scene/15-Scene/04/1015.jpg
#  extracting: 15-Scene/15-Scene/04/1016.jpg
#  extracting: 15-Scene/15-Scene/04/1017.jpg
#  extracting: 15-Scene/15-Scene/04/1018.jpg
#  extracting: 15-Scene/15-Scene/04/1019.jpg
#  extracting: 15-Scene/15-Scene/04/1020.jpg
#  extracting: 15-Scene/15-Scene/04/1021.jpg
#  extracting: 15-Scene/15-Scene/04/1022.jpg
#  extracting: 15-Scene/15-Scene/04/1023.jpg
#  extracting: 15-Scene/15-Scene/04/1024.jpg
#  extracting: 15-Scene/15-Scene/04/1025.jpg
#  extracting: 15-Scene/15-Scene/04/1026.jpg
#  extracting: 15-Scene/15-Scene/04/1027.jpg
#  extracting: 15-Scene/15-Scene/04/1028.jpg
#  extracting: 15-Scene/15-Scene/04/1029.jpg
#  extracting: 15-Scene/15-Scene/04/1030.jpg
#  extracting: 15-Scene/15-Scene/04/1031.jpg
#  extracting: 15-Scene/15-Scene/04/1032.jpg
#  extracting: 15-Scene/15-Scene/04/1033.jpg
#  extracting: 15-Scene/15-Scene/04/1034.jpg
#  extracting: 15-Scene/15-Scene/04/1035.jpg
#  extracting: 15-Scene/15-Scene/04/1036.jpg
#  extracting: 15-Scene/15-Scene/04/1037.jpg
#  extracting: 15-Scene/15-Scene/04/1038.jpg
#  extracting: 15-Scene/15-Scene/04/1039.jpg
#  extracting: 15-Scene/15-Scene/04/1040.jpg
#  extracting: 15-Scene/15-Scene/04/1041.jpg
#  extracting: 15-Scene/15-Scene/04/1042.jpg
#  extracting: 15-Scene/15-Scene/04/1043.jpg
#  extracting: 15-Scene/15-Scene/04/1044.jpg
#  extracting: 15-Scene/15-Scene/04/1045.jpg
#  extracting: 15-Scene/15-Scene/04/1046.jpg
#  extracting: 15-Scene/15-Scene/04/1047.jpg
#  extracting: 15-Scene/15-Scene/04/1048.jpg
#  extracting: 15-Scene/15-Scene/04/1049.jpg
#  extracting: 15-Scene/15-Scene/04/1050.jpg
#  extracting: 15-Scene/15-Scene/04/1051.jpg
#  extracting: 15-Scene/15-Scene/04/1052.jpg
#  extracting: 15-Scene/15-Scene/04/1053.jpg
#  extracting: 15-Scene/15-Scene/04/1054.jpg
#  extracting: 15-Scene/15-Scene/04/1055.jpg
#  extracting: 15-Scene/15-Scene/04/1056.jpg
#  extracting: 15-Scene/15-Scene/04/1057.jpg
#  extracting: 15-Scene/15-Scene/04/1058.jpg
#  extracting: 15-Scene/15-Scene/04/1059.jpg
#   inflating: 15-Scene/15-Scene/04/1060.jpg
#  extracting: 15-Scene/15-Scene/04/1061.jpg
#  extracting: 15-Scene/15-Scene/04/1062.jpg
#   inflating: 15-Scene/15-Scene/04/1063.jpg
#  extracting: 15-Scene/15-Scene/04/1064.jpg
#  extracting: 15-Scene/15-Scene/04/1065.jpg
#  extracting: 15-Scene/15-Scene/04/1066.jpg
#  extracting: 15-Scene/15-Scene/04/1067.jpg
#  extracting: 15-Scene/15-Scene/04/1068.jpg
#  extracting: 15-Scene/15-Scene/04/1069.jpg
#   inflating: 15-Scene/15-Scene/04/1070.jpg
#  extracting: 15-Scene/15-Scene/04/1071.jpg
#  extracting: 15-Scene/15-Scene/04/1072.jpg
#  extracting: 15-Scene/15-Scene/04/1073.jpg
#  extracting: 15-Scene/15-Scene/04/1074.jpg
#  extracting: 15-Scene/15-Scene/04/1075.jpg
#  extracting: 15-Scene/15-Scene/04/1076.jpg
#  extracting: 15-Scene/15-Scene/04/1077.jpg
#  extracting: 15-Scene/15-Scene/04/1078.jpg
#  extracting: 15-Scene/15-Scene/04/1079.jpg
#  extracting: 15-Scene/15-Scene/04/1080.jpg
#  extracting: 15-Scene/15-Scene/04/1081.jpg
#  extracting: 15-Scene/15-Scene/04/1082.jpg
#  extracting: 15-Scene/15-Scene/04/1083.jpg
#  extracting: 15-Scene/15-Scene/04/1084.jpg
#  extracting: 15-Scene/15-Scene/04/1085.jpg
#   inflating: 15-Scene/15-Scene/04/1086.jpg
#  extracting: 15-Scene/15-Scene/04/1087.jpg
#  extracting: 15-Scene/15-Scene/04/1088.jpg
#  extracting: 15-Scene/15-Scene/04/1089.jpg
#  extracting: 15-Scene/15-Scene/04/1090.jpg
#   inflating: 15-Scene/15-Scene/04/1091.jpg
#   inflating: 15-Scene/15-Scene/04/1092.jpg
#  extracting: 15-Scene/15-Scene/04/1093.jpg
#  extracting: 15-Scene/15-Scene/04/1094.jpg
#  extracting: 15-Scene/15-Scene/04/1095.jpg
#   inflating: 15-Scene/15-Scene/04/1096.jpg
#  extracting: 15-Scene/15-Scene/04/1097.jpg
#  extracting: 15-Scene/15-Scene/04/1098.jpg
#   inflating: 15-Scene/15-Scene/04/1099.jpg
#   inflating: 15-Scene/15-Scene/04/1100.jpg
#  extracting: 15-Scene/15-Scene/04/1101.jpg
#   inflating: 15-Scene/15-Scene/04/1102.jpg
#  extracting: 15-Scene/15-Scene/04/1103.jpg
#   inflating: 15-Scene/15-Scene/04/1104.jpg
#  extracting: 15-Scene/15-Scene/04/1105.jpg
#  extracting: 15-Scene/15-Scene/04/1106.jpg
#  extracting: 15-Scene/15-Scene/04/1107.jpg
#  extracting: 15-Scene/15-Scene/04/1108.jpg
#  extracting: 15-Scene/15-Scene/04/1109.jpg
# ...
#  extracting: 15-Scene/15-Scene/13/4132.jpg
#  extracting: 15-Scene/15-Scene/13/4133.jpg
#  extracting: 15-Scene/15-Scene/13/4134.jpg
#  extracting: 15-Scene/15-Scene/13/4135.jpg
#  extracting: 15-Scene/15-Scene/13/4136.jpg
#  extracting: 15-Scene/15-Scene/13/4137.jpg
#   inflating: 15-Scene/15-Scene/13/4138.jpg
#  extracting: 15-Scene/15-Scene/13/4139.jpg
#  extracting: 15-Scene/15-Scene/13/4140.jpg
#  extracting: 15-Scene/15-Scene/13/4141.jpg
#  extracting: 15-Scene/15-Scene/13/4142.jpg
#  extracting: 15-Scene/15-Scene/13/4143.jpg
#  extracting: 15-Scene/15-Scene/13/4144.jpg
#  extracting: 15-Scene/15-Scene/13/4145.jpg
#  extracting: 15-Scene/15-Scene/13/4146.jpg
#  extracting: 15-Scene/15-Scene/13/4147.jpg
#   inflating: 15-Scene/15-Scene/13/4148.jpg
#   inflating: 15-Scene/15-Scene/13/4149.jpg
#   inflating: 15-Scene/15-Scene/13/4150.jpg
#  extracting: 15-Scene/15-Scene/13/4151.jpg
#  extracting: 15-Scene/15-Scene/13/4152.jpg
#  extracting: 15-Scene/15-Scene/13/4153.jpg
#   inflating: 15-Scene/15-Scene/13/4154.jpg
#  extracting: 15-Scene/15-Scene/13/4155.jpg
#  extracting: 15-Scene/15-Scene/13/4156.jpg
#  extracting: 15-Scene/15-Scene/13/4157.jpg
#  extracting: 15-Scene/15-Scene/13/4158.jpg
#  extracting: 15-Scene/15-Scene/13/4159.jpg
#  extracting: 15-Scene/15-Scene/13/4160.jpg
#  extracting: 15-Scene/15-Scene/13/4161.jpg
#   inflating: 15-Scene/15-Scene/13/4162.jpg
#  extracting: 15-Scene/15-Scene/13/4163.jpg
#  extracting: 15-Scene/15-Scene/13/4164.jpg
#  extracting: 15-Scene/15-Scene/13/4165.jpg
#  extracting: 15-Scene/15-Scene/13/4166.jpg
#  extracting: 15-Scene/15-Scene/13/4167.jpg
#   inflating: 15-Scene/15-Scene/13/4168.jpg
#  extracting: 15-Scene/15-Scene/13/4169.jpg
#   inflating: 15-Scene/15-Scene/13/4170.jpg
#    creating: 15-Scene/15-Scene/14/
#   inflating: 15-Scene/15-Scene/14/4171.jpg
#   inflating: 15-Scene/15-Scene/14/4172.jpg
#   inflating: 15-Scene/15-Scene/14/4173.jpg
#   inflating: 15-Scene/15-Scene/14/4174.jpg
#   inflating: 15-Scene/15-Scene/14/4175.jpg
#   inflating: 15-Scene/15-Scene/14/4176.jpg
#   inflating: 15-Scene/15-Scene/14/4177.jpg
#   inflating: 15-Scene/15-Scene/14/4178.jpg
#   inflating: 15-Scene/15-Scene/14/4179.jpg
#   inflating: 15-Scene/15-Scene/14/4180.jpg
#   inflating: 15-Scene/15-Scene/14/4181.jpg
#   inflating: 15-Scene/15-Scene/14/4182.jpg
#   inflating: 15-Scene/15-Scene/14/4183.jpg
#   inflating: 15-Scene/15-Scene/14/4184.jpg
#   inflating: 15-Scene/15-Scene/14/4185.jpg
#   inflating: 15-Scene/15-Scene/14/4186.jpg
#   inflating: 15-Scene/15-Scene/14/4187.jpg
#   inflating: 15-Scene/15-Scene/14/4188.jpg
#   inflating: 15-Scene/15-Scene/14/4189.jpg
#   inflating: 15-Scene/15-Scene/14/4190.jpg
#   inflating: 15-Scene/15-Scene/14/4191.jpg
#   inflating: 15-Scene/15-Scene/14/4192.jpg
#   inflating: 15-Scene/15-Scene/14/4193.jpg
#   inflating: 15-Scene/15-Scene/14/4194.jpg
#   inflating: 15-Scene/15-Scene/14/4195.jpg
#   inflating: 15-Scene/15-Scene/14/4196.jpg
#   inflating: 15-Scene/15-Scene/14/4197.jpg
#   inflating: 15-Scene/15-Scene/14/4198.jpg
#   inflating: 15-Scene/15-Scene/14/4199.jpg
#   inflating: 15-Scene/15-Scene/14/4200.jpg
#   inflating: 15-Scene/15-Scene/14/4201.jpg
#   inflating: 15-Scene/15-Scene/14/4202.jpg
#   inflating: 15-Scene/15-Scene/14/4203.jpg
#   inflating: 15-Scene/15-Scene/14/4204.jpg
#   inflating: 15-Scene/15-Scene/14/4205.jpg
#   inflating: 15-Scene/15-Scene/14/4206.jpg
#   inflating: 15-Scene/15-Scene/14/4207.jpg
#   inflating: 15-Scene/15-Scene/14/4208.jpg
#   inflating: 15-Scene/15-Scene/14/4209.jpg
#   inflating: 15-Scene/15-Scene/14/4210.jpg
#   inflating: 15-Scene/15-Scene/14/4211.jpg
#   inflating: 15-Scene/15-Scene/14/4212.jpg
#   inflating: 15-Scene/15-Scene/14/4213.jpg
#   inflating: 15-Scene/15-Scene/14/4214.jpg
#   inflating: 15-Scene/15-Scene/14/4215.jpg
#   inflating: 15-Scene/15-Scene/14/4216.jpg
#   inflating: 15-Scene/15-Scene/14/4217.jpg
#   inflating: 15-Scene/15-Scene/14/4218.jpg
#   inflating: 15-Scene/15-Scene/14/4219.jpg
#   inflating: 15-Scene/15-Scene/14/4220.jpg
#   inflating: 15-Scene/15-Scene/14/4221.jpg
#   inflating: 15-Scene/15-Scene/14/4222.jpg
#   inflating: 15-Scene/15-Scene/14/4223.jpg
#   inflating: 15-Scene/15-Scene/14/4224.jpg
#   inflating: 15-Scene/15-Scene/14/4225.jpg
#   inflating: 15-Scene/15-Scene/14/4226.jpg
#   inflating: 15-Scene/15-Scene/14/4227.jpg
#   inflating: 15-Scene/15-Scene/14/4228.jpg
#   inflating: 15-Scene/15-Scene/14/4229.jpg
#   inflating: 15-Scene/15-Scene/14/4230.jpg
#   inflating: 15-Scene/15-Scene/14/4231.jpg
#   inflating: 15-Scene/15-Scene/14/4232.jpg
#   inflating: 15-Scene/15-Scene/14/4233.jpg
#   inflating: 15-Scene/15-Scene/14/4234.jpg
#   inflating: 15-Scene/15-Scene/14/4235.jpg
#   inflating: 15-Scene/15-Scene/14/4236.jpg
#   inflating: 15-Scene/15-Scene/14/4237.jpg
#   inflating: 15-Scene/15-Scene/14/4238.jpg
#   inflating: 15-Scene/15-Scene/14/4239.jpg
#   inflating: 15-Scene/15-Scene/14/4240.jpg
#   inflating: 15-Scene/15-Scene/14/4241.jpg
#   inflating: 15-Scene/15-Scene/14/4242.jpg
#   inflating: 15-Scene/15-Scene/14/4243.jpg
#   inflating: 15-Scene/15-Scene/14/4244.jpg
#   inflating: 15-Scene/15-Scene/14/4245.jpg
#   inflating: 15-Scene/15-Scene/14/4246.jpg
#   inflating: 15-Scene/15-Scene/14/4247.jpg
#   inflating: 15-Scene/15-Scene/14/4248.jpg
#   inflating: 15-Scene/15-Scene/14/4249.jpg
#   inflating: 15-Scene/15-Scene/14/4250.jpg
#   inflating: 15-Scene/15-Scene/14/4251.jpg
#   inflating: 15-Scene/15-Scene/14/4252.jpg
#   inflating: 15-Scene/15-Scene/14/4253.jpg
#   inflating: 15-Scene/15-Scene/14/4254.jpg
#   inflating: 15-Scene/15-Scene/14/4255.jpg
#   inflating: 15-Scene/15-Scene/14/4256.jpg
#   inflating: 15-Scene/15-Scene/14/4257.jpg
#   inflating: 15-Scene/15-Scene/14/4258.jpg
#   inflating: 15-Scene/15-Scene/14/4259.jpg
#   inflating: 15-Scene/15-Scene/14/4260.jpg
#   inflating: 15-Scene/15-Scene/14/4261.jpg
#   inflating: 15-Scene/15-Scene/14/4262.jpg
#   inflating: 15-Scene/15-Scene/14/4263.jpg
#   inflating: 15-Scene/15-Scene/14/4264.jpg
#   inflating: 15-Scene/15-Scene/14/4265.jpg
#   inflating: 15-Scene/15-Scene/14/4266.jpg
#   inflating: 15-Scene/15-Scene/14/4267.jpg
#   inflating: 15-Scene/15-Scene/14/4268.jpg
#   inflating: 15-Scene/15-Scene/14/4269.jpg
#   inflating: 15-Scene/15-Scene/14/4270.jpg
#   inflating: 15-Scene/15-Scene/14/4271.jpg
#   inflating: 15-Scene/15-Scene/14/4272.jpg
#   inflating: 15-Scene/15-Scene/14/4273.jpg
#   inflating: 15-Scene/15-Scene/14/4274.jpg
#   inflating: 15-Scene/15-Scene/14/4275.jpg
#   inflating: 15-Scene/15-Scene/14/4276.jpg
#   inflating: 15-Scene/15-Scene/14/4277.jpg
#   inflating: 15-Scene/15-Scene/14/4278.jpg
#   inflating: 15-Scene/15-Scene/14/4279.jpg
#   inflating: 15-Scene/15-Scene/14/4280.jpg
#   inflating: 15-Scene/15-Scene/14/4281.jpg
#   inflating: 15-Scene/15-Scene/14/4282.jpg
#   inflating: 15-Scene/15-Scene/14/4283.jpg
#   inflating: 15-Scene/15-Scene/14/4284.jpg
#   inflating: 15-Scene/15-Scene/14/4285.jpg
#   inflating: 15-Scene/15-Scene/14/4286.jpg
#   inflating: 15-Scene/15-Scene/14/4287.jpg
#   inflating: 15-Scene/15-Scene/14/4288.jpg
#   inflating: 15-Scene/15-Scene/14/4289.jpg
#   inflating: 15-Scene/15-Scene/14/4290.jpg
#   inflating: 15-Scene/15-Scene/14/4291.jpg
#   inflating: 15-Scene/15-Scene/14/4292.jpg
#   inflating: 15-Scene/15-Scene/14/4293.jpg
#   inflating: 15-Scene/15-Scene/14/4294.jpg
#   inflating: 15-Scene/15-Scene/14/4295.jpg
#   inflating: 15-Scene/15-Scene/14/4296.jpg
#   inflating: 15-Scene/15-Scene/14/4297.jpg
#   inflating: 15-Scene/15-Scene/14/4298.jpg
#   inflating: 15-Scene/15-Scene/14/4299.jpg
#   inflating: 15-Scene/15-Scene/14/4300.jpg
#   inflating: 15-Scene/15-Scene/14/4301.jpg
#   inflating: 15-Scene/15-Scene/14/4302.jpg
#   inflating: 15-Scene/15-Scene/14/4303.jpg
#   inflating: 15-Scene/15-Scene/14/4304.jpg
#   inflating: 15-Scene/15-Scene/14/4305.jpg
#   inflating: 15-Scene/15-Scene/14/4306.jpg
#   inflating: 15-Scene/15-Scene/14/4307.jpg
#   inflating: 15-Scene/15-Scene/14/4308.jpg
#   inflating: 15-Scene/15-Scene/14/4309.jpg
#   inflating: 15-Scene/15-Scene/14/4310.jpg
#   inflating: 15-Scene/15-Scene/14/4311.jpg
#   inflating: 15-Scene/15-Scene/14/4312.jpg
#   inflating: 15-Scene/15-Scene/14/4313.jpg
#   inflating: 15-Scene/15-Scene/14/4314.jpg
#   inflating: 15-Scene/15-Scene/14/4315.jpg
#   inflating: 15-Scene/15-Scene/14/4316.jpg
#   inflating: 15-Scene/15-Scene/14/4317.jpg
#   inflating: 15-Scene/15-Scene/14/4318.jpg
#   inflating: 15-Scene/15-Scene/14/4319.jpg
#   inflating: 15-Scene/15-Scene/14/4320.jpg
#   inflating: 15-Scene/15-Scene/14/4321.jpg
#   inflating: 15-Scene/15-Scene/14/4322.jpg
#   inflating: 15-Scene/15-Scene/14/4323.jpg
#   inflating: 15-Scene/15-Scene/14/4324.jpg
#   inflating: 15-Scene/15-Scene/14/4325.jpg
#   inflating: 15-Scene/15-Scene/14/4326.jpg
#   inflating: 15-Scene/15-Scene/14/4327.jpg
#   inflating: 15-Scene/15-Scene/14/4328.jpg
#   inflating: 15-Scene/15-Scene/14/4329.jpg
#   inflating: 15-Scene/15-Scene/14/4330.jpg
#   inflating: 15-Scene/15-Scene/14/4331.jpg
#   inflating: 15-Scene/15-Scene/14/4332.jpg
#   inflating: 15-Scene/15-Scene/14/4333.jpg
#   inflating: 15-Scene/15-Scene/14/4334.jpg
#   inflating: 15-Scene/15-Scene/14/4335.jpg
#   inflating: 15-Scene/15-Scene/14/4336.jpg
#   inflating: 15-Scene/15-Scene/14/4337.jpg
#   inflating: 15-Scene/15-Scene/14/4338.jpg
#   inflating: 15-Scene/15-Scene/14/4339.jpg
#   inflating: 15-Scene/15-Scene/14/4340.jpg
#   inflating: 15-Scene/15-Scene/14/4341.jpg
#   inflating: 15-Scene/15-Scene/14/4342.jpg
#   inflating: 15-Scene/15-Scene/14/4343.jpg
#   inflating: 15-Scene/15-Scene/14/4344.jpg
#   inflating: 15-Scene/15-Scene/14/4345.jpg
#   inflating: 15-Scene/15-Scene/14/4346.jpg
#   inflating: 15-Scene/15-Scene/14/4347.jpg
#   inflating: 15-Scene/15-Scene/14/4348.jpg
#   inflating: 15-Scene/15-Scene/14/4349.jpg
#   inflating: 15-Scene/15-Scene/14/4350.jpg
#   inflating: 15-Scene/15-Scene/14/4351.jpg
#   inflating: 15-Scene/15-Scene/14/4352.jpg
#   inflating: 15-Scene/15-Scene/14/4353.jpg
#   inflating: 15-Scene/15-Scene/14/4354.jpg
#   inflating: 15-Scene/15-Scene/14/4355.jpg
#   inflating: 15-Scene/15-Scene/14/4356.jpg
#   inflating: 15-Scene/15-Scene/14/4357.jpg
#   inflating: 15-Scene/15-Scene/14/4358.jpg
#   inflating: 15-Scene/15-Scene/14/4359.jpg
#   inflating: 15-Scene/15-Scene/14/4360.jpg
#   inflating: 15-Scene/15-Scene/14/4361.jpg
#   inflating: 15-Scene/15-Scene/14/4362.jpg
#   inflating: 15-Scene/15-Scene/14/4363.jpg
#   inflating: 15-Scene/15-Scene/14/4364.jpg
#   inflating: 15-Scene/15-Scene/14/4365.jpg
#   inflating: 15-Scene/15-Scene/14/4366.jpg
#   inflating: 15-Scene/15-Scene/14/4367.jpg
#   inflating: 15-Scene/15-Scene/14/4368.jpg
#   inflating: 15-Scene/15-Scene/14/4369.jpg
#   inflating: 15-Scene/15-Scene/14/4370.jpg
#   inflating: 15-Scene/15-Scene/14/4371.jpg
#   inflating: 15-Scene/15-Scene/14/4372.jpg
#   inflating: 15-Scene/15-Scene/14/4373.jpg
#   inflating: 15-Scene/15-Scene/14/4374.jpg
#   inflating: 15-Scene/15-Scene/14/4375.jpg
#   inflating: 15-Scene/15-Scene/14/4376.jpg
#   inflating: 15-Scene/15-Scene/14/4377.jpg
#   inflating: 15-Scene/15-Scene/14/4378.jpg
#   inflating: 15-Scene/15-Scene/14/4379.jpg
#   inflating: 15-Scene/15-Scene/14/4380.jpg
#   inflating: 15-Scene/15-Scene/14/4381.jpg
#   inflating: 15-Scene/15-Scene/14/4382.jpg
#   inflating: 15-Scene/15-Scene/14/4383.jpg
#   inflating: 15-Scene/15-Scene/14/4384.jpg
#   inflating: 15-Scene/15-Scene/14/4385.jpg
#   inflating: 15-Scene/15-Scene/14/4386.jpg
#   inflating: 15-Scene/15-Scene/14/4387.jpg
#   inflating: 15-Scene/15-Scene/14/4388.jpg
#   inflating: 15-Scene/15-Scene/14/4389.jpg
#   inflating: 15-Scene/15-Scene/14/4390.jpg
#   inflating: 15-Scene/15-Scene/14/4391.jpg
#   inflating: 15-Scene/15-Scene/14/4392.jpg
#   inflating: 15-Scene/15-Scene/14/4393.jpg
#   inflating: 15-Scene/15-Scene/14/4394.jpg
#   inflating: 15-Scene/15-Scene/14/4395.jpg
#   inflating: 15-Scene/15-Scene/14/4396.jpg
#   inflating: 15-Scene/15-Scene/14/4397.jpg
#   inflating: 15-Scene/15-Scene/14/4398.jpg
#   inflating: 15-Scene/15-Scene/14/4399.jpg
#   inflating: 15-Scene/15-Scene/14/4400.jpg
#   inflating: 15-Scene/15-Scene/14/4401.jpg
#   inflating: 15-Scene/15-Scene/14/4402.jpg
#   inflating: 15-Scene/15-Scene/14/4403.jpg
#   inflating: 15-Scene/15-Scene/14/4404.jpg
#   inflating: 15-Scene/15-Scene/14/4405.jpg
#   inflating: 15-Scene/15-Scene/14/4406.jpg
#   inflating: 15-Scene/15-Scene/14/4407.jpg
#   inflating: 15-Scene/15-Scene/14/4408.jpg
#   inflating: 15-Scene/15-Scene/14/4409.jpg
#   inflating: 15-Scene/15-Scene/14/4410.jpg
#   inflating: 15-Scene/15-Scene/14/4411.jpg
#   inflating: 15-Scene/15-Scene/14/4412.jpg
#   inflating: 15-Scene/15-Scene/14/4413.jpg
#   inflating: 15-Scene/15-Scene/14/4414.jpg
#   inflating: 15-Scene/15-Scene/14/4415.jpg
#   inflating: 15-Scene/15-Scene/14/4416.jpg
#   inflating: 15-Scene/15-Scene/14/4417.jpg
#   inflating: 15-Scene/15-Scene/14/4418.jpg
#   inflating: 15-Scene/15-Scene/14/4419.jpg
#   inflating: 15-Scene/15-Scene/14/4420.jpg
#   inflating: 15-Scene/15-Scene/14/4421.jpg
#   inflating: 15-Scene/15-Scene/14/4422.jpg
#   inflating: 15-Scene/15-Scene/14/4423.jpg
#   inflating: 15-Scene/15-Scene/14/4424.jpg
#   inflating: 15-Scene/15-Scene/14/4425.jpg
#   inflating: 15-Scene/15-Scene/14/4426.jpg
#   inflating: 15-Scene/15-Scene/14/4427.jpg
#   inflating: 15-Scene/15-Scene/14/4428.jpg
#   inflating: 15-Scene/15-Scene/14/4429.jpg
#   inflating: 15-Scene/15-Scene/14/4430.jpg
#   inflating: 15-Scene/15-Scene/14/4431.jpg
#   inflating: 15-Scene/15-Scene/14/4432.jpg
#   inflating: 15-Scene/15-Scene/14/4433.jpg
#   inflating: 15-Scene/15-Scene/14/4434.jpg
#   inflating: 15-Scene/15-Scene/14/4435.jpg
#   inflating: 15-Scene/15-Scene/14/4436.jpg
#   inflating: 15-Scene/15-Scene/14/4437.jpg
#   inflating: 15-Scene/15-Scene/14/4438.jpg
#   inflating: 15-Scene/15-Scene/14/4439.jpg
#   inflating: 15-Scene/15-Scene/14/4440.jpg
#   inflating: 15-Scene/15-Scene/14/4441.jpg
#   inflating: 15-Scene/15-Scene/14/4442.jpg
#   inflating: 15-Scene/15-Scene/14/4443.jpg
#   inflating: 15-Scene/15-Scene/14/4444.jpg
#   inflating: 15-Scene/15-Scene/14/4445.jpg
#   inflating: 15-Scene/15-Scene/14/4446.jpg
#   inflating: 15-Scene/15-Scene/14/4447.jpg
#   inflating: 15-Scene/15-Scene/14/4448.jpg
#   inflating: 15-Scene/15-Scene/14/4449.jpg
#   inflating: 15-Scene/15-Scene/14/4450.jpg
#   inflating: 15-Scene/15-Scene/14/4451.jpg
#   inflating: 15-Scene/15-Scene/14/4452.jpg
#   inflating: 15-Scene/15-Scene/14/4453.jpg
#   inflating: 15-Scene/15-Scene/14/4454.jpg
#   inflating: 15-Scene/15-Scene/14/4455.jpg
#   inflating: 15-Scene/15-Scene/14/4456.jpg
#   inflating: 15-Scene/15-Scene/14/4457.jpg
#   inflating: 15-Scene/15-Scene/14/4458.jpg
#   inflating: 15-Scene/15-Scene/14/4459.jpg
#   inflating: 15-Scene/15-Scene/14/4460.jpg
#   inflating: 15-Scene/15-Scene/14/4461.jpg
#   inflating: 15-Scene/15-Scene/14/4462.jpg
#   inflating: 15-Scene/15-Scene/14/4463.jpg
#   inflating: 15-Scene/15-Scene/14/4464.jpg
#   inflating: 15-Scene/15-Scene/14/4465.jpg
#   inflating: 15-Scene/15-Scene/14/4466.jpg
#   inflating: 15-Scene/15-Scene/14/4467.jpg
#   inflating: 15-Scene/15-Scene/14/4468.jpg
#   inflating: 15-Scene/15-Scene/14/4469.jpg
#   inflating: 15-Scene/15-Scene/14/4470.jpg
#   inflating: 15-Scene/15-Scene/14/4471.jpg
#   inflating: 15-Scene/15-Scene/14/4472.jpg
#   inflating: 15-Scene/15-Scene/14/4473.jpg
#   inflating: 15-Scene/15-Scene/14/4474.jpg
#   inflating: 15-Scene/15-Scene/14/4475.jpg
#   inflating: 15-Scene/15-Scene/14/4476.jpg
#   inflating: 15-Scene/15-Scene/14/4477.jpg
#   inflating: 15-Scene/15-Scene/14/4478.jpg
#   inflating: 15-Scene/15-Scene/14/4479.jpg
#   inflating: 15-Scene/15-Scene/14/4480.jpg
#   inflating: 15-Scene/15-Scene/14/4481.jpg
#   inflating: 15-Scene/15-Scene/14/4482.jpg
#   inflating: 15-Scene/15-Scene/14/4483.jpg
#   inflating: 15-Scene/15-Scene/14/4484.jpg
#   inflating: 15-Scene/15-Scene/14/4485.jpg

# %%
import torch
import os
import pandas as pd
import numpy as np
import warnings
# from functions import train_model, evaluate_model, detailed_evaluation, read_config
from torchvision import models
from torchvision.models.efficientnet import EfficientNet_B0_Weights
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Subset
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


class CustomDataset(Dataset):
    def __init__(self, img_dir, transform):
        super().__init__()
        self.img_dir = img_dir
        self.transform = transform
        self.images = []
        self.labels = []
        for label in os.listdir(self.img_dir):
            img_folder_path = os.path.join(self.img_dir, label)
            for img in os.listdir(img_folder_path):
                img_path = os.path.join(img_folder_path, img)
                self.images.append(img_path)
                self.labels.append(int(label))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = Image.open(self.images[idx]).convert('RGB')
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label


def train_model(model, dataloader, validation_loader, epochs, optimizer, entropyloss):
    print("\n-----------   Model training   -----------\n")
    best_accuracy = 0
    best_model = None
    size_loader = len(dataloader)
    for epoch in range(epochs):
        running_loss = 0.0
        model.train()  # set model to training mode
        for images, labels in dataloader:
            prediction = model(images) # predicted outputs
            loss = entropyloss(prediction, labels) # entropy loss

            optimizer.zero_grad() # reset the gradients of model parameters
            loss.backward() # backpropagate the prediction loss
            optimizer.step() # adjust the parameters by the gradients collected in the backward pass

            running_loss += loss.item()

        epoch_loss = running_loss / size_loader
        validation_loss, validation_accuracy = validate_model(model, validation_loader, entropyloss)
        print(f'Epoch {epoch + 1}, Train Loss: {epoch_loss:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}')

        # Save the model if it has the best accuracy so far
        if validation_accuracy > best_accuracy:
            best_accuracy = validation_accuracy
            best_model = model.state_dict()  # save the model parameters
            print("Best model updated")

    print("Training complete. Best Accuracy: {:.2f}%".format(best_accuracy))
    return best_model


def validate_model(model, validation_loader, entropyloss):
    print("\n-----------   Model validation   -----------\n")
    model.eval()  # Set model to evaluation mode
    validation_loss = 0.0
    correct = 0
    total = 0
    size_loader = len(validation_loader)

    with torch.no_grad():
        for images, labels in validation_loader:
            prediction = model(images)
            validation_loss += entropyloss(prediction, labels).item()

            correct += (prediction.argmax(1) == labels).type(torch.float).sum().item()
            total += labels.size(0)

    validation_loss /= size_loader
    validation_accuracy = correct / total
    return validation_loss, validation_accuracy


def evaluate_test(model, dataloader, entropyloss):
    print("\n-----------   Test evaluation   -----------\n")
    model.eval()
    all_predictions = []
    all_labels = []
    total_loss = 0.0
    size_loader = len(dataloader)

    with torch.no_grad():
        for images, labels in dataloader:
            outputs = model(images)
            loss = entropyloss(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / size_loader
    accuracy = accuracy_score(all_labels, all_predictions)
    print(f"Average Loss: {avg_loss:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(classification_report(all_labels, all_predictions))
    print("Confusion Matrix:\n", confusion_matrix(all_labels, all_predictions))

# %%
warnings.filterwarnings('ignore')
epochs=10
learning_rate = 1e-3
batch_size = 64
data_path = '15-Scene/15-Scene'
# config = read_config('config.txt')
# epochs = config['epochs']
# learning_rate = config['learning_rate']
# batch_size = config['batch_size']
# data_path = config['data_path']

# def read_config(file_path): # read configuration file
#     config = {}
#     with open(file_path, 'r') as file:
#         for line in file:
#             key, value = line.strip().split('=')
#             config[key.strip()] = value.strip()
#     return config


# load pre-trained EfficientNet-B0
efficientnet = models.efficientnet_b0(weights=True, pretrained=True)

# make all layers trainable
for param in efficientnet.parameters():
    param.requires_grad = True

transform = EfficientNet_B0_Weights.IMAGENET1K_V1.transforms()
# optimizer and entropy loss function used
optimizer = torch.optim.Adam(efficientnet.parameters(), lr=learning_rate)
entropyloss = torch.nn.CrossEntropyLoss()
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 86.9MB/s]

# %%
# ########### FULLY SUPERVISED MODEL

scene_data = CustomDataset(img_dir=data_path, transform=transform) # load data from the folders into scene_data

# Obtain labels for each index
total_size = len(scene_data)
indices = list(range(total_size))
labels = [scene_data[i][1] for i in indices]

# Stratified split using scikit-learn's train_test_split
train_set_idx, validation_set_idx, _, _ = train_test_split(indices, labels, test_size=0.3, random_state=42, stratify=labels)
validation_set_idx, test_set_idx, _, _ = train_test_split(validation_set_idx, [labels[i] for i in validation_set_idx], test_size=0.5, random_state=42, stratify=[labels[i] for i in validation_set_idx])

# Create subset data loaders
train_dataset = Subset(scene_data, train_set_idx)
validation_dataset = Subset(scene_data, validation_set_idx)
test_dataset = Subset(scene_data, test_set_idx)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
validation_loader = DataLoader(validation_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)


# ######### FULLY SUPERVISED

# # train the model with the train loader in how many epochs you want
# best_model = train_model(model=efficientnet, dataloader=train_loader, validation_loader=validation_loader, epochs=epochs, optimizer=optimizer, entropyloss=entropyloss)
# efficientnet.load_state_dict(best_model)  # Load the best model parameters

# # Call the detailed evaluation function
# evaluate_test(efficientnet, test_loader)

# %%
from PIL import Image
import cv2
from torch.utils.data import Dataset, DataLoader
import torch
from torchvision import transforms, models
from torchvision.models.efficientnet import EfficientNet_B0_Weights

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class CustomBlurDataset(Dataset):
    def __init__(self, img_dir, transform):
        super().__init__()
        self.img_dir = img_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.kernel_sizes = [(5, 5), (9, 9), (13, 13), (17, 17), (21, 21)]

        for label in os.listdir(self.img_dir):
            img_folder_path = os.path.join(self.img_dir, label)
            for img in os.listdir(img_folder_path):
                img_path = os.path.join(img_folder_path, img)
                self.images.append(img_path)
                self.labels.append(int(label))

    def __len__(self):
        return len(self.images) * len(self.kernel_sizes) #

    def __getitem__(self, idx):
        img_idx = idx // len(self.kernel_sizes)
        kernel_idx = idx % len(self.kernel_sizes)

        image = Image.open(self.images[img_idx]).convert('RGB')
        kernel_size = self.kernel_sizes[kernel_idx]

        image_np = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
        blurred_image = cv2.GaussianBlur(image_np, kernel_size, sigmaX=0)
        blurred_image = Image.fromarray(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))

        if self.transform:
            blurred_image = self.transform(blurred_image)

        label = kernel_idx
        return blurred_image, label


def train_blurred_model(model, dataloader, epochs, optimizer, entropyloss):
    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            prediction = model(images) # predicted outputs
            loss = entropyloss(prediction, labels) # entropy loss

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(prediction, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_loss = running_loss / len(dataloader)
        epoch_accuracy = correct / total
        print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}")

        return model

# %%
############# BLUR
import torch.nn as nn

# # load pre-trained EfficientNet-B0
# efficientnet = models.efficientnet_b0(weights=True, pretrained=True)

# # make all layers trainable
# for param in efficientnet.parameters():
#     param.requires_grad = True

# transform = EfficientNet_B0_Weights.IMAGENET1K_V1.transforms()
# # optimizer and entropy loss function used
# optimizer = torch.optim.Adam(efficientnet.parameters(), lr=learning_rate)
# entropyloss = torch.nn.CrossEntropyLoss()


# Modify the classifier to predict the blur kernel size
num_features = efficientnet.classifier[1].in_features
efficientnet.classifier = torch.nn.Sequential(
    torch.nn.Dropout(p=0.2),
    torch.nn.Linear(num_features, 5)  # 5 classes for the 5 kernel sizes
)
efficientnet.to(device)

# Create the dataset
blurred_data = CustomBlurDataset(img_dir=data_path, transform=transform)

# Create data loaders
train_blurred_loader = DataLoader(blurred_data, batch_size=batch_size, shuffle=True)

efficientnet = train_blurred_model(model=efficientnet, dataloader=train_blurred_loader, epochs=epochs, optimizer=optimizer, entropyloss=entropyloss)

num_scene_classes = 15           ################# SOSSSS FIX IT DYNAMICALLY ###################
efficientnet.classifier = nn.Sequential(
    nn.Dropout(p=0.2),
    nn.Linear(num_features, num_scene_classes)
)

efficientnet = train_blurred_model(model=efficientnet, dataloader=train_loader, epochs=epochs, optimizer=optimizer, entropyloss=entropyloss)

evaluate_test(efficientnet, test_loader)



# # pick a picture
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]

img_np = img.permute(1, 2, 0).cpu().numpy()  # Reorder the dimensions
img_np = (img_np * 0.5) + 0.5
print(f"Label: {label}")
plt.imshow(img_np, cmap="gray")
plt.show()
